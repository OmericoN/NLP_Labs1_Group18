# %% [markdown]
# (#18)
#
# - Omer Nidam
# - Julian Kinkel
# - Raul Parau
#
#
# Raul - i6399837
#
# Use of genAI tools (e.g. chatGPT), websites (e.g. stackoverflow):
#
#  - We used GenAI in some of our plot code to ensure correct plot behaviour and not risk faulty experiments
#
#
# Mention names of collaborators outside your group

# %% [markdown]
# # NLP 2026
# # Lab 1: From Tokens to Language Models
#
# As discussed in the first lectures, tokenization is a fundamental step in **Natural Language Processing (NLP)** 🧠💬 that transforms raw text into structured data for computational models. In this lab, you will explore different **tokenization techniques** 📝, preprocess text data 🔍, and implement **tokenization pipelines** using popular NLP libraries 🏗️. Next, we explore N-gram language models 📊 as a foundational approach 🧱 to modeling natural language statistically 📈. These models form the conceptual foundation 🧠 of the neural language models 🤖🧠 that we will explore later in the course 🚀📚.
#
# You will also gain **hands-on experience** with **Hugging Face Datasets 🤗📚**, while assessing the impact of tokenization choices on downstream NLP tasks.
#
# By the end of this lab, you will have a **strong foundation** in tokenization techniques and be able to apply them effectively in **real-world NLP applications**, including implementing a N-gram language modeling pipeline🌍.
#
# ---
#
# ### 🎯 **Learning Goals**
#
# By the end of this lab, you should be able to:
#
# ✅ **Understand the role of tokenization in NLP** 🧠💡
# ✅ **Explain why tokenization is important** and how it affects text processing 📖🔍
# ✅ **Implement different tokenization techniques** – Apply **word** 📝, **subword** 🔢, and **character-level** 🔠 tokenization using built-in libraries.
# ✅ **Use Hugging Face Datasets** 🤗📊 – Load and preprocess text datasets efficiently.
# ✅ **Evaluate tokenization impact** 📉🔎 – Analyze how different tokenization methods influence model performance.
# ✅ **Identify challenges in tokenization** ❗🔍 – Recognize issues like **out-of-vocabulary (OOV) words**, **ambiguity**, and **multilingual tokenization** 🌍.
# ✅ **Identify challenges in tokenization** ❗🔍 – Recognize issues like **out-of-vocabulary (OOV) words**, **ambiguity** and **multilingual tokenization** 🌍.
# ✅ **Build and use N-gram language models** 🧠📊 - Understand how unigrams, bigrams and higher-order n-grams capture context in text, implement efficient N-gram counting with Python and design an object-oriented N-gram Language Model that supports probability lookup and text generation.
# ✅ **Generate, smooth and evaluate language models** 🚀📉 - Apply different techniques for text generation and compare models with different values of $N$ and advanced techniques such as interpolation or backoff.
#
# ### Score breakdown
#
# | Exercise            | Points |
# |---------------------|--------|
# | [Exercise 1](#e1)   | 3      |
# | [Exercise 2](#e2)   | 6      |
# | [Exercise 3](#e3)   | 4      |
# | [Exercise 4](#e4)   | 6      |
# | [Exercise 5](#e5)   | 4      |
# | [Exercise 6](#e6)   | 7      |
# | [Exercise 7](#e7)   | 4      |
# | [Exercise 8](#e8)   | 4      |
# | [Exercise 9](#e9)   | 4      |
# | [Exercise 10](#e10) | 6      |
# | [Exercise 11](#e11) | 4      |
# | [Exercise 12](#e12) | 4      |
# | [Exercise 13](#e13) | 4      |
# | [Exercise 14](#e14) | 4      |
# | [Exercise 15](#e15) | 4      |
# | [Exercise 16](#e16) | 4      |
# | [Exercise 17](#e17) | 4      |
# | [Exercise 18](#e18) | 4      |
# | [Exercise 19](#e19) | 20     |
# | Total               | 100    |
#
# This score will be scaled down to X.X and that will be your final lab score.
#
# ### 📌 **Instructions for Delivery** (📅 **Deadline: X/Feb 18:00**, 🎭 *wildcards possible*)
#
# ✅ **Submission Requirements**
# + 📄 You need to submit a **notebook** 📓 with the code, appropriate comments and figures in all questions. Make sure to have a mix of code (some explanations needed if not clear what you implement), figures to support the answers or your claims and proper amount of text to explain your reasoning, answer etc.
# + ⚡ Make sure that **all cells are executed properly** ⚙️ and that **all figures/results/plots** 📊 you include in the report are also visible in your **executed notebook**.
# + You can work on Google Collab (or other environments), but you need to make sure that your delivered notebook is executed properly.
#
# ✅ **Collaboration & Integrity**
# + 🗣️ While you may **discuss** the lab with others, you must **write your solutions with your group only**. If you **discuss specific tasks** with others, please **include their names** below.
# + 📜 **Honor Code applies** to this lab. For more details, check **Syllabus §7.2** ⚖️.
# + 📢 **Mandatory Disclosure**:
#    - Any **websites** 🌐 (e.g., **Stack Overflow** 💡) or **other resources** used must be **listed and disclosed**.
#    - Any **GenAI tools** 🤖 (e.g., **ChatGPT**) used must be **explicitly mentioned**.
#    - 🚨 **Failure to disclose these resources is a violation of academic integrity**. See **Syllabus §7.3** for details.

# %% [markdown]
# **A note from Jerry on using Language Models (LMs)**
#
# If you try hard enough, you will likely get away with cheating (that does not only apply to LMs). Fortunately, our job is not to police, but rather to educate you. So, please consider the following:
#
# - We assume that you are taking this course to learn something! LMs are not always right (they often fail in silly ways). This course should prepare you to detect when they are wrong!
# - We don't restrict the use of LMs because we see the value of being helped when coding (esp. in the context of a course like NLP). Based on what we saw last year in your deliverables, it's pretty clear when you "copy" some code and then you struggle to interpret the results. This is the essence of this course and of the skills you should try build for yourself: Many people can run fancy models these days but not many people can interpret the results correctly. Try to be the latter ones.

# %% [markdown]
# ## 0. Preparation
#
# In this section we will import the necessary libraries. But first we will explain how to install a python environment using conda. You don't have to do it this way, and maybe you already have one prepared.
#
# First, you can install Miniconda environment manager. Here are the instructions https://www.anaconda.com/docs/getting-started/miniconda/install.
# It can create virtual environments with different python versions and separately installed libraries (useful if  you work on several projects). You can read more about managing environments here: https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html
# You might need a restart of your system to complete the installation.
#
# The commands below are commented out so that you don't run them by mistake. You will have to copy them to the terminal of your operating system.

# %% [markdown]
# This command creates a new environment called `nlplab2026` (you can change the name if you'd like) and python version `3.12`.

# %%
# conda create -n nlplab2026 python=3.12

# %% [markdown]
# The environment should be installed, but it is not activated yet. To do it you can use the following command:

# %%
# conda activate nlplab2026

# %% [markdown]
# The activation of the environment is indicated by the prompt (the name of the environment should be in parentheses), for example: `(nlplab2026) pawelmaka@MacBook ~ % `
#
# Now, we are ready to install the required packages using `pip`:

# %%
# pip install --user --upgrade jupyter
# pip install tqdm
# pip install datasets
# pip install matplotlib
# pip install numpy
# pip install pandas

# %% [markdown]
# Sometimes, the libraries don't work together well on some systems. This situation could necessitate the installation of a library's particular version. To do so you can use the following command (putting the library and version you need)

# %%
# pip install matplotlib==3.10.8 --force-reinstall -v

# %% [markdown]
# When you are starting jupyter notebook make sure to first activate the environment `nlplab2026`.

# %% [markdown]
# ### Imports

# %%
import re
from collections import Counter

import datasets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tqdm

# %% [markdown]
# ### Intro to regular expressions
#
# In this introduction section, you can practice the use of regular expressions in python. You can find the documentation here: [https://docs.python.org/3/library/re.html](https://docs.python.org/3/library/re.html). The main functions of the re module are:
# - `re.search()` - searches for a pattern in a string, returns the first match,
# - `re.findall()` - similar to `search()`, but returns a list of all matches,
# - `re.sub()` - replaces the matches with a string.
#
# All above functions accept the regular expression pattern as their argument. The patterns are strings that represent the rules for matching the text. In python they start with `r` character, e.g. `r'\d'` is a pattern that matches a digit.
#
# Let us start with a simple example. We will search for the word "world" in the string "Hello, world!".

# %%
text = "Hello, world!"
pattern = r'world'
match = re.search(pattern, text)
print(match)
# Out:
# <re.Match object; span=(7, 12), match='world'>

# %% [markdown]
# The `search()` function returns a match object that tells us where the match was found (`span` argument) and the exact part of the string that matched the pattern (`group` argument).
#
# Below you can find the examples from the lecture.

# %%
# Disjunctions
pattern = r'[wW]oodchuck'  # matches both "woodchuck" and "Woodchuck"
pattern = r'[1234567890]'  # matches any digit, you can also use r'\d' or r'[0-9]'
pattern = r'[0-9]'  # matches any digit
pattern = r'[A-Z]'  # matches any uppercase letter
pattern = r'[a-z]'  # matches any lowercase letter
pattern = r'[A-Za-z]'  # matches any letter

# Disjunctions with pipe |
pattern = r'groundhog|Woodchuck'  # matches both "groundhog" and "Woodchuck"

# Negation (only when in [])
pattern = r'[^0-9]'  # matches any character that is not a digit
pattern = r'[^Ss]'  # matches any character that is not 'S' or 's'
pattern = r'a\^b'  # matches the string "a^b"

# Quantifiers (+, *, ?, .)
pattern = r'baa+'  # matches "ba" followed by one or more "a" (e.g. "baa", "baaa", "baaaa", ...)
pattern = r'oo*h'  # matches "o" followed by zero or more "o" and then "h" (e.g. "oh", "ooh", "oooh", ...)
pattern = r'colou?r'  # matches "color" and "colour"
pattern = r'beg.n'  # matches "begun", "begin", "begnn", ...

# Anchors (^, $)
pattern = r'^Hello'  # matches "Hello" at the beginning of the string
pattern = r'world!$'  # matches "world!" at the end of the string

# %% [markdown]
# ## 1. Hugging Face Datasets
#
# We will be using Hugging Face Datasets library ([https://huggingface.co/datasets](https://huggingface.co/datasets)). You can find the detailed documentation and tutorials here: [https://huggingface.co/docs/datasets/en/index](https://huggingface.co/docs/datasets/en/index)
#
# In this lab, we will load “tweet_eval” dataset and specifically the __emoji__ subset. For tokenization, we will only consider the text (contents of the tweet) but in this section we will also look at the labels. The description of the dataset is available in the dataset's card at [https://huggingface.co/datasets/cardiffnlp/tweet_eval](https://huggingface.co/datasets/cardiffnlp/tweet_eval)
#
# In order to load a dataset simply call load_dataset function specifying the dataset name. You can find many more datasets at the huggingface website.

# %%
dataset = datasets.load_dataset('tweet_eval', 'emoji')
print(dataset)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# The loaded dataset contains three subsets (“train”, “validation”, and “test”). Each consists of two columns: “text” and “label”. Label is an integer from 0 to 19 representing an emoji. See the dataset's card for more information. We can access the elements of the dataset like so:

# %%
for i in range(10):
    print(dataset['train'][i])
# Out:
# {'text': 'Sunday afternoon walking through Venice in the sun with @user ️ ️ ️ @ Abbot Kinney, Venice', 'label': 12}
# {'text': "Time for some BBQ and whiskey libations. Chomp, belch, chomp! (@ Lucille's Smokehouse Bar-B-Que)", 'label': 19}
# {'text': 'Love love love all these people ️ ️ ️ #friends #bff #celebrate #blessed #sundayfunday @ San…', 'label': 0}
# {'text': '️ ️ ️ ️ @ Toys"R"Us', 'label': 0}
# {'text': 'Man these are the funniest kids ever!! That face! #HappyBirthdayBubb @ FLIPnOUT Xtreme', 'label': 2}
# {'text': '#sandiego @ San Diego, California', 'label': 11}
# {'text': 'My little ️ ️ ️ ️ ️ #ObsessedWithMyDog @ Cafe Solstice Capitol Hill', 'label': 0}
# {'text': 'More #tinyepic things #tinyepicwestern, this one is crazy @user I may be one of your…', 'label': 19}
# {'text': 'Last night ️ @ Omnia Night Club At Caesars Palace', 'label': 0}
# {'text': 'friendship at its finest. ....#pixar #toystory #buzz #woody #friends #friendship #bff…', 'label': 7}

# %% [markdown]
# You can easily cast the dataset to the pandas DataFrame.

# %%
tweet_train_df = pd.DataFrame(dataset['train'])
print(tweet_train_df)
# Out:
#                                                     text  label
# 0      Sunday afternoon walking through Venice in the...     12
# 1      Time for some BBQ and whiskey libations. Chomp...     19
# 2      Love love love all these people ️ ️ ️ #friends...      0
# 3                                    ️ ️ ️ ️ @ Toys"R"Us      0
# 4      Man these are the funniest kids ever!! That fa...      2
# ...                                                  ...    ...
# 44995  Here to celebrate the Nunez wedding! Love my b...      0
# 44996  1 night in Paris.... Wait... @ Paris Las Vegas...      1
# 44997  Be safe this weekend everyone. #happylaborday ...     11
# 44998          Pizza (@ Five50 - @user in Las Vegas, NV)      1
# 44999  my mini is perfect, no one deserves her @ Las ...     13
#
# [45000 rows x 2 columns]

# %% [markdown]
# Even though we will not use the labels in this lab, we can plot their distribution in the training subset.

# %% [markdown]
# ### Dataset's filter function
# We can filter the examples using ```filter()``` method. See this link for more details https://huggingface.co/docs/datasets/en/use_dataset. Here is an example of filtering the short tweets (less than 20 characters) from the ```train``` subset.

# %%
short_tweets = dataset['train'].filter(lambda example: len(example['text']) < 20)
print(short_tweets)
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 506
# })

# %%
for i in range(10):
    print(short_tweets[i])
# Out:
# {'text': '️ ️ ️ ️ @ Toys"R"Us', 'label': 0}
# {'text': '️ @ Columbia River', 'label': 12}
# {'text': 'My weekend: @user 3', 'label': 6}
# {'text': 'good day today', 'label': 3}
# {'text': 'My last RT...', 'label': 2}
# {'text': '@ On Lake Cowichan', 'label': 13}
# {'text': '@ Macroplaza', 'label': 4}
# {'text': '@ BART Train', 'label': 6}
# {'text': '️ 4 a tbh&amp; rate', 'label': 0}
# {'text': '@user Oh nice!!', 'label': 14}

# %% [markdown]
# ### Dataset's map function
# Datasets library contains a very useful method map. It expects a function that will receive an example from the dataset. This function will be applied to all entries. We will calculate the length of the text (in characters) in each example.

# %%
def calculate_text_length(example):
    example['text_length'] = len(example['text'])
    return example

# %%
dataset = dataset.map(calculate_text_length, desc="Calculating text length")
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'text_length'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# We can plot the histogram of the text lengths.

# %%
pd.DataFrame(dataset['train']).groupby('text_length')['text_length'].count().plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# <a name='e1'></a>
#
# ### Exercise 1: Questions about the datasets
# 1. (1p) What is the size of the training, test and validation datasets?
# 2. (1p) What is the average length (in characters) of the tweets in the training dataset?
# 3. (1p) Compare the distributions of tweet lengths between training, validation, and test subsets.

# %%
size_train = len(dataset['train'])
size_test = len(dataset['test'])
size_val = len(dataset['validation'])
print(f"The training set size is = {size_train}")
print(f"The test set size is = {size_test}")
print(f"The validation set size is = {size_val}")
# Out:
# The training set size is = 45000
# The test set size is = 50000
# The validation set size is = 5000

# %%
df_tlengths = pd.DataFrame(dataset['train'])
avg = df_tlengths['text_length'].mean()
df_tlengths['text_length'].describe()
# Out:
# count    45000.000000
# mean        71.016911
# std         22.248420
# min          6.000000
# 25%         55.000000
# 50%         76.000000
# 75%         90.000000
# max        142.000000
# Name: text_length, dtype: float64

# %%
##### You can add code here but feel free to add/remove cells as you see fit
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

pd.DataFrame(dataset['train']) \
    ['text_length'] \
    .plot.hist(bins=50, ax=axes[0], title='Train')

pd.DataFrame(dataset['test']) \
    ['text_length'] \
    .plot.hist(bins=50, ax=axes[1], title='Test')

pd.DataFrame(dataset['validation']) \
    ['text_length'] \
    .plot.hist(bins=50, ax=axes[2], title='Validation')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Answers
#
# 1. Train set has size 45000, Test set has size 50000, Validation set has size 5000. The size is equal to the number of rows.
# 2. 71.016911 ≈ 71
# 3. You can see that for all train, test and validation set the length has a clear cut at 100 characters. There are only a few texts with more than a 100 characters, indicating a probable maximum lenght of a 100 characters. While the distributions of Train and Test set look very similar with a signigifcant peak at around 90 - 100 characters, and another smaller peak at 60-70 characters, the validation set distribution shows a slightly different pattern. There, the peaks at 60 words and 100 words are closer to each other with respect to the frequency of the according text lengths.

# %% [markdown]
# ## 2. Tokenization
#
# In this section we will preprocess the dataset by cleaning and tokenizing the entries.
# Datasets library contains a very useful method map. It expects a function that will receive an example from the dataset. This function will be applied to all entries.

# %% [markdown]
# ### 2.1 Cleaning the text

# %% [markdown]
# <a name='e2'></a>
#
# ### Exercise 2: Write the text cleaning function
#
# (6p) Include at least the following steps:
# 1. remove comma between numbers, i.e. 15,000 -> 15000,
# 2. remove multiple spaces,
# 3. space out the punctuation (i.e. "hello, world." -> "hello , world ."),
# 4. three more cleaning steps of your choice.

# %%
def clean(text):
    """
    Cleans the text
    Args:
        text: a string that will be cleaned

    Returns: the cleaned text

    """

    # Empty text
    if text == '':
        return text

    ### YOUR CODE HERE
    # removing comma between numbers
    text = re.sub(r'(\d),(\d)', '', text)

    # remove multiple spaces
    text = re.sub(r'\s+', ' ', text)

    # space out punctuation
    text = re.sub(r'([.,!?;:])', r' \1', text)

    #Optional cleaning
    # lowercase senetence
    text = text.lower()

    # stripping sentence to remove tailing/leading spaces
    text = text.strip()

    ### YOUR CODE ENDS HERE

    return text

# %% [markdown]
# Let's test your cleaning function

# %%
for i in range(5):
    original = dataset['train'][i]['text']
    cleaned = clean(original)
    print('original:', original)
    print('cleaned:', cleaned)
    print()
# Out:
# original: sunday afternoon walking through venice in the sun with @user ️ ️ ️ @ abbot kinney , venice
# cleaned: sunday afternoon walking through venice in the sun with @ user ️ ️ ️ @ abbot kinney  , venice
#
# original: time for some bbq and whiskey libations . chomp , belch , chomp ! (@ lucille's smokehouse bar-b-que)
# cleaned: time for some bbq and whiskey libations  . chomp  , belch  , chomp  ! (@ lucille's smokehouse bar-b-que)
#
# original: love love love all these people ️ ️ ️ #friends #bff #celebrate #blessed #sundayfunday @ san…
# cleaned: love love love all these people ️ ️ ️ # friends # bff # celebrate # blessed # sundayfunday @ san…
#
# original: ️ ️ ️ ️ @ toys"r"us
# cleaned: ️ ️ ️ ️ @ toys"r"us
#
# original: man these are the funniest kids ever ! ! that face ! #happybirthdaybubb @ flipnout xtreme
# cleaned: man these are the funniest kids ever  !  ! that face  ! # happybirthdaybubb @ flipnout xtreme

# %% [markdown]
# Let's finally use the ```map()``` method and apply your `clean()` function to all entries of the dataset. We are overriding the `text` field with the cleaned version.

# %%
def clean_example(example):
    """
    Cleans the example from the Dataset. Uses clean() function for cleaning.
    Args:
        example: an example from the Dataset

    Returns: update example containing 'clean' column

    """
    text = example['text']
    clean_text = clean(text)

    # Update the example with the cleaned text
    example['text'] = clean_text.strip()
    return example


dataset = dataset.map(clean_example, desc="Cleaning text")
print(dataset)
# Out:
# Cleaning text:   0%|          | 0/45000 [00:00<?, ? examples/s]
# Cleaning text:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Cleaning text:   0%|          | 0/5000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# ### 2.2 Build vocabulary
#
# In the previous section, we implemented the cleaning of the dataset. Now, we will tokenize the text splitting it by spaces. We will build a vocabulary based on the cleaned text of the `train` split. We will investigate some properties of corpora (e.g. Zipf's law).
#
# The function below builds a vocabulary from the dataset. It counts the occurrences of the words in the dataset using the Counter class. Check the documentation here [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter).

# %% [markdown]
# <a name='e3'></a>
# ### Exercise 3: Build the vocabulary
# (4p) Fill in the function below to build the vocabulary from the dataset. The function should return a `Counter` object with the words and their frequencies. The variable named `vocab` is already initialized as an empty `Counter` object.

# %%
def build_vocab_counter(dataset):
    """
    Builds a vocabulary from the dataset
    Args:
        dataset: a dataset

    Returns: a vocabulary

    """
    vocab = Counter()

    ### YOUR CODE HERE

    for sample in dataset:
        words = sample['text'].split()
        vocab.update(words)

    ### YOUR CODE ENDS HERE
    return vocab

# %%
vocab_counter = build_vocab_counter(dataset['train'])
print('Size of the vocabulary:', len(vocab_counter))
# Out:
# Size of the vocabulary: 62956

# %% [markdown]
# Because we created a counter, we can easily check the most and least common words in the vocabulary. Do the most common words make sense? How about the least common ones?

# %%
print('Most common:')
print(vocab_counter.most_common(10))
print('Least common:')
print(vocab_counter.most_common()[-10:])
# Out:
# Most common:
# [('#', 55469), ('@', 36536), ('.', 23674), ('!', 16957), ('the', 13407), (',', 12384), ('user', 12236), ('️', 9936), ('to', 7655), ('my', 7503)]
# Least common:
# [('corban…', 1), ('southbayla', 1), ('thedabberchick', 1), ('nector', 1), ('chefking1921express', 1), ('rolltide', 1), ('bffweekend', 1), ('nunez', 1), ('happylaborday', 1), ('five50', 1)]

# %% [markdown]
# We can also plot the counts of the words. You can check the [Power law](https://en.wikipedia.org/wiki/Power_law) if you are more interested.

# %%
import matplotlib.pyplot as plt

plt.loglog([val for word, val in vocab_counter.most_common()])
plt.xlabel('rank')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# The plot shows that the distribution of the words in the vocabulary follows the Zipf's law. The most frequent word occurs approximately twice as often as the second most frequent word, three times as often as the third most frequent word, etc.
#
# We can also filter the vocabulary by the frequency of the words. We will only consider the most frequent words and mark the rest as the `<unk>` token. Here we set the maximum vocabulary size to 50,000. But you can experiment with different sizes.

# %%
# prune vocabulary
max_vocab_size = 50000
vocab = vocab_counter.most_common(max_vocab_size)
# cast to list of words
vocab = [word for word, _ in vocab]
print(len(vocab))
# Out:
# 50000

# %% [markdown]
# <a name='e4'></a>
# ### Exercise 4: Frequency of pairs of words
# Calculate the frequency of (neighbouring) pairs of words in the training dataset.
# 1. (2p) List the most and least common pairs. Do the most common pairs make sense?
# 2. (2p) How many pairs occur only once in the dataset?
# 3. (2p) Plot the distribution of the pair frequencies.

# %%
### YOUR CODE HERE

def build_bigram_counter(dataset): 
    
    bigrams = Counter()

    for sample in dataset: 
        words = sample['text'].split()
        for i in range(len(words) - 1):
            pair = (words[i], words[i+1])
            bigrams[pair] += 1

    return bigrams

def build_bigram_counter_only_words(dataset):
    token_re = re.compile(r'\w+')  # keeps letters/digits/underscore
    bigrams = Counter()
    for sample in dataset:
        toks = [t for t in sample['text'].split() if token_re.fullmatch(t)]
        for i in range(len(toks)-1):
            bigrams[(toks[i], toks[i+1])] += 1
    return bigrams

# %%
bigram_counter = build_bigram_counter(dataset['train'])
bigram_counter_words = build_bigram_counter_only_words(dataset['train'])

# %%
print("Most common bigrams: ")

bigram_counter.most_common(10)
# Out:
# Most common bigrams:
# [(('@', 'user'), 12236),
#  (('.', '.'), 7726),
#  (('!', '!'), 4946),
#  ((',', 'california'), 3339),
#  (('️', '@'), 3268),
#  (('.', '#'), 2778),
#  (('!', '#'), 2614),
#  (('user', '@'), 2440),
#  (('️', '️'), 2240),
#  (('&amp', ';'), 2019)]

# %%
'''
Most common bigrams 
'''
print("Most common words: ")

bigram_counter_words.most_common(10)
# Out:
# Most common words:
# [(('los', 'angeles'), 1722),
#  (('user', 'user'), 1104),
#  (('with', 'my'), 1071),
#  (('in', 'the'), 1000),
#  (('las', 'vegas'), 982),
#  (('i', 'love'), 848),
#  (('for', 'the'), 847),
#  (('thank', 'you'), 803),
#  (('angeles', 'california'), 801),
#  (('at', 'the'), 765)]

# %%
'''
Least common bigrams 
'''
print("Least common bigrams: ")
bigram_counter.most_common()[-10:]
# Out:
# Least common bigrams:
# [(('#', 'happylaborday'), 1),
#  (('happylaborday', '@'), 1),
#  (('@', 'beer'), 1),
#  (('beer', 'nv'), 1),
#  (('pizza', '('), 1),
#  (('@', 'five50'), 1),
#  (('five50', '-'), 1),
#  (('mini', 'is'), 1),
#  (('one', 'deserves'), 1),
#  (('deserves', 'her'), 1)]

# %%
print("Least common word bigrams: ")
bigram_counter_words.most_common()[-10:]
# Out:
# Least common word bigrams:
# [(('everyone', 'happylaborday'), 1),
#  (('happylaborday', 'beer'), 1),
#  (('beer', 'nv'), 1),
#  (('pizza', 'five50'), 1),
#  (('five50', 'user'), 1),
#  (('mini', 'is'), 1),
#  (('perfect', 'no'), 1),
#  (('one', 'deserves'), 1),
#  (('deserves', 'her'), 1),
#  (('her', 'las'), 1)]

# %%
'''
How many appear only once
'''

i = sum(1 for count in bigram_counter.values() if count == 1)
print(f"Number of bigrams that appear once = {i}")
# Out:
# Number of bigrams that appear once = 192473

# %%
frequencies = list(bigram_counter.values())
freq_distribution = Counter(frequencies)
x = list(freq_distribution.keys())
y = list(freq_distribution.values())

plt.figure()
plt.plot(x, y, marker='o')
plt.xscale('log') 
plt.yscale('log')  
plt.xlabel("Bigram frequency (log scale)")
plt.ylabel("Number of bigrams (log scale)")
plt.title("Distribution of bigram frequencies")
plt.grid(True, alpha=0.3)  
plt.show()

# %% [markdown]
# ### ANSWER
#
# We decided to to this exercise in two ways. First we consider all bigrams, including special letters like @ or # and then we do it again but onyl with words.
#
# #### Most common:
#
# The most common bigrams (including everything) were:
# ('@', 'user'), 12236,
# ('.', '.'), 7726,
# ('!', '!'), 4946,
# (',', 'california'), 3339,
# ('️', '@'), 3268,
# ('.', '#'), 2778,
# ('!', '#'), 2614,
# ('user', '@'), 2440,
# ('️', '️'), 2240,
# ('&amp', ';'), 2019
#
# You can see that this is a lot of punctuation and signs like # or @. This makes total sense as we are dealing with tweets that are naturally very expressive, and use these signs a lot.
#
# But because we wanted to see which words actually appear often together we did the same with filtering out these signs. Then the most common bigrams became:
#
# ('los', 'angeles'), 1722,
# ('user', 'user'), 1104,
# ('with', 'my'), 1071,
# ('in', 'the'), 1000,
# ('las', 'vegas'), 982,
# ('i', 'love'), 848,
# ('for', 'the'), 847,
# ('thank', 'you'), 803,
# ('angeles', 'california'), 801,
# ('at', 'the'), 765
#
# As you can see these are words that naturally often appear together like "thank you", "las vegas" "I love" etc. These results are to be expected and show that our bigram function is working correctly. The most common bigrams are words that naturally appear together.
#
# #### Least common:
#
# Least common bigrams including signs:
#
# ('#', 'happylaborday'), 1,
# ('happylaborday', '@'), 1,
# ('@', 'beer'), 1,
# ('beer', 'nv'), 1,
# ('pizza', ''), 1,
# ('@', 'five50'), 1,
# ('five50', '-'), 1,
# ('mini', 'is'), 1,
# ('one', 'deserves'), 1,
# ('deserves', 'her'), 1
#
# Least Common bigrams (onyl words):
#
# ('everyone', 'happylaborday'), 1,
# ('happylaborday', 'beer'), 1,
# ('beer', 'nv'), 1,
# ('pizza', 'five50'), 1,
# ('five50', 'user'), 1,
# ('mini', 'is'), 1,
# ('perfect', 'no'), 1,
# ('one', 'deserves'), 1,
# ('deserves', 'her'), 1,
# ('her', 'las'), 1
#
# All of the least common bigrams appear only once. Furthermore they do not carry any meaning and are not expressive at all. Therefore it is reasonable that they appeaer rarely.
#
# #### How many bigrams appear once?
#
# Number of bigrams that appear once = 192473
#
# #### Plot
#
# The plot can be seen above

# %% [markdown]
# We will define and add three special tokens to our vocabulary:
# - unknown token ```<unk>```, which will represent words outside our vocabulary;
# - begining of sequence token ```<s>```, which will always be the first token of a sequence;
# - end of sequence token ```</s>```, which will mark the end of the sequence and allow the model to finish generation.

# %%
unknown_token = '<unk>'
bos_token = '<s>'
eos_token = '</s>'
vocab.append(unknown_token)
vocab.append(bos_token)
vocab.append(eos_token)

# %% [markdown]
# ### 2.3 Tokenize the dataset
# The function below tokenizes the cleaned text (```example['clean']```) by splitting it on spaces. It replaces the words that are not in the vocabulary with the `<unk>` token.

# %% [markdown]
# <a name='e5'></a>
# ### Exercise 5: Tokenize the dataset
# (4p) Fill in the function below to tokenize the dataset. The function will be applied to the dataset through the `map()` method, so it returns the updated example. Your task is to split the text by spaces and replace the words that are not in the vocabulary with the `<unk>` token. The tokenized sequence should start with the `bos_token` token and end with the 'eos_token'.

# %%
def tokenize(text, vocab, unknown_token='<unk>', bos_token='<s>', eos_token='</s>'):
    """
    Tokenizes the text that is assumed to be cleaned first with the clean() function. The tokenized sequence should start with the `bos_token` token and end with the 'eos_token'.
    Args:
        text: a cleaned text
        vocab: a vocabulary as a list of words
        unknown_token: a token to replace the words that are not in the vocabulary
    Returns: tokenized text as a list of tokens

    """

    tokens = None  # list of tokens, your code should fill this variable

    ### YOUR CODE HERE
    tokens = text.split(" ")
    for i in range(len(tokens)):
        if tokens[i] not in vocab:
            tokens[i] = unknown_token
    
    tokens.insert(0, bos_token)
    tokens.append(eos_token)



    ### YOUR CODE ENDS HERE

    return tokens

# %% [markdown]
# Let's test the function:

# %%
tokenized = tokenize("what are you doing someunknowntoken ?", vocab, unknown_token, bos_token, eos_token)
print(tokenized)

assert tokenized[0] == bos_token, "First token should be bos_token"
assert tokenized[-1] == eos_token, "Last token should be eos_token"
# Out:
# ['<s>', 'what', 'are', 'you', 'doing', '<unk>', '?', '</s>']

# %%
def tokenize_example(example, vocab, unknown_token='<unk>', bos_token='<s>', eos_token='</s>'):
    """
    Applies the tokenize() function to the example from the Dataset
    Args:
        example: an example from the Dataset
        vocab: a vocabulary as a list of words
        unknown_token: a token to replace the words that are not in the vocabulary
    Returns: update example containing 'tokens' column

    """
    text = example['text']
    tokens = tokenize(text, vocab, unknown_token, bos_token, eos_token)
    example['tokens'] = tokens
    return example


dataset = dataset.map(tokenize_example,
                      fn_kwargs={
                          'vocab': vocab,
                          'unknown_token': unknown_token,
                          'bos_token': bos_token,
                          'eos_token': eos_token,
                      }, desc="Tokenizing text")
print(dataset)
# Out:
# Tokenizing text:   0%|          | 0/45000 [00:00<?, ? examples/s]
# Tokenizing text:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Tokenizing text:   0%|          | 0/5000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 45000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 50000
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'text_length', 'tokens'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# Let us examine several entries from the dataset. We can see that the `tokens` column has been added to each example.

# %%
for i in range(5):
    print('Original tweet:')
    print(dataset['train'][i]['text'])
    print('Tokenized tweet:')
    print(dataset['train'][i]['tokens'])
# Out:
# Original tweet:
# sunday afternoon walking through venice in the sun with @ user ️ ️ ️ @ abbot kinney , venice
# Tokenized tweet:
# ['<s>', 'sunday', 'afternoon', 'walking', 'through', 'venice', 'in', 'the', 'sun', 'with', '@', 'user', '️', '️', '️', '@', 'abbot', 'kinney', ',', 'venice', '</s>']
# Original tweet:
# time for some bbq and whiskey libations . chomp , belch , chomp ! ( @ lucille's smokehouse bar-b-que )
# Tokenized tweet:
# ['<s>', 'time', 'for', 'some', 'bbq', 'and', 'whiskey', 'libations', '.', 'chomp', ',', 'belch', ',', 'chomp', '!', '(', '@', "lucille's", 'smokehouse', 'bar-b-que', ')', '</s>']
# Original tweet:
# love love love all these people ️ ️ ️ # friends # bff # celebrate # blessed # sundayfunday @ san…
# Tokenized tweet:
# ['<s>', 'love', 'love', 'love', 'all', 'these', 'people', '️', '️', '️', '#', 'friends', '#', 'bff', '#', 'celebrate', '#', 'blessed', '#', 'sundayfunday', '@', 'san…', '</s>']
# Original tweet:
# ️ ️ ️ ️ @ toys"r"us
# Tokenized tweet:
# ['<s>', '️', '️', '️', '️', '@', 'toys"r"us', '</s>']
# Original tweet:
# man these are the funniest kids ever ! ! that face ! # happybirthdaybubb @ flipnout xtreme
# Tokenized tweet:
# ['<s>', 'man', 'these', 'are', 'the', 'funniest', 'kids', 'ever', '!', '!', 'that', 'face', '!', '#', 'happybirthdaybubb', '@', 'flipnout', 'xtreme', '</s>']

# %% [markdown]
# Make sure that the tokenization works as you intended. If not, revisit the cleaning and tokenization functions.

# %% [markdown]
# <a name='e6'></a>
# ### Exercise 6: Questions about the tokenization
# 1. (1p) How many unknown tokens are in the validation dataset after tokenization?
# 2. (1p) What is the distribution of the number of tokens in the training dataset?
# 3. (1p) How the number of tokens corresponds to the number of characters in our dataset?
# 4. (1p) How the size of the vocabulary (```max_vocab_size```) affects the number of unknown tokens?
# 5. (1p) How does the size of the vocabulary affect the number of tokens in the dataset?
# 6. (1p) Think about the advantages and disadvantages of the tokenization method we used. What are the cases when it will not work well?
# 7. (1p) Decide what vocabulary size you will use for the rest of the lab. It shouldn't be smaller than 10,000. Give a short explanation.

# %%
### YOUR CODE HERE
#### Question 1
df_6_valid = pd.DataFrame(dataset['validation'])
total_unknown = 0
for tokens in df_6_valid['tokens']:
    total_unknown += tokens.count(unknown_token)
print(f"the total number of unknown tokens is: {total_unknown}")
# Out:
# the total number of unknown tokens is: 5995

# %%
#### Question 2
df_6_train = pd.DataFrame(dataset['train'])
num_tokens = [len(tokens) for tokens in df_6_train['tokens']]

# plot histogram of token counts
plt.figure(figsize=(8,4))
plt.hist(num_tokens, bins=range(0, max(num_tokens) + 2), edgecolor='black')
plt.xlabel('number of tokens')
plt.ylabel('number of tweets')
plt.title('Distribution of tokens per tweet')
plt.tight_layout()
plt.show()

# %% [markdown]
# --- YOUR ANSWERS HERE

# %%
#### Question 3
n_tokens_train = []
n_chars = df_6_train['text'].str.len()
for tokens in df_6_train['tokens']:
    n_tokens_train.append(len(tokens) - 2) #minus the BOS and EOS

corr = np.corrcoef(n_tokens_train, n_chars)[0, 1]
print(f"The pearson correlation coefficient between characters and tokens is: {corr}")
plt.figure(figsize=(6, 4))
plt.scatter(n_chars, n_tokens_train, s=5, alpha=0.2)
plt.xlabel("Number of characters (cleaned text)")
plt.ylabel("Number of tokens (excluding <s>, </s>)")
plt.title("Tokens vs characters")
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(n_chars, n_tokens_train, 'o', markeredgewidth=0.1 )
plt.xlabel("Number of characters (cleaned text)")
plt.ylabel("Number of tokens (excluding <s>, </s>)")
plt.title("Tokens vs characters")
plt.tight_layout()
plt.show()

n_tokens_train = (df_6_train['tokens'].apply(len) - 2).to_numpy()  # exclude BOS/EOS
n_chars = df_6_train['text'].str.len().to_numpy()
tokens_per_char = n_tokens_train / np.where(n_chars == 0, 1, n_chars)  # avoid div0

print(f"Mean tokens/char: {tokens_per_char.mean():.4f}, Median: {np.median(tokens_per_char):.4f}")

plt.figure(figsize=(6,4))
plt.hist(tokens_per_char, bins=50, edgecolor='black')
plt.xlabel("Tokens per character")
plt.ylabel("Number of tweets")
plt.title("Distribution of tokens/character ratio")
plt.tight_layout()
plt.show()
# Out:
# The pearson correlation coefficient between characters and tokens is: 0.89287230668411
# Mean tokens/char: 0.2018, Median: 0.2000

# %%
#### Question 4: How vocab size affects number of <unk> tokens

def build_vocab_topk(vocab_counter, k, unknown_token="<unk>", bos_token="<s>", eos_token="</s>"):
    # top-k most frequent tokens from our train set
    vocab_k = [w for w, _ in vocab_counter.most_common(k)]
    # add special tokens 
    vocab_k = vocab_k + [unknown_token, bos_token, eos_token]
    return vocab_k

def count_unk_in_split(split, vocab_k, unknown_token="<unk>", bos_token="<s>", eos_token="</s>"):
    total_unk = 0
    for ex in split:
        toks = tokenize(ex["text"], vocab_k, unknown_token, bos_token, eos_token)
        total_unk += toks.count(unknown_token)
    return total_unk

# reasonable increasing range
ks = np.linspace(1000, 50000, 25, dtype=int)  # 25 points from 1k to 50k
unks = []

for k in ks:
    vocab_k = build_vocab_topk(vocab_counter, int(k), unknown_token, bos_token, eos_token)
    unks.append(count_unk_in_split(dataset["validation"], vocab_k, unknown_token, bos_token, eos_token))

plt.figure(figsize=(6,4))
plt.plot(ks, unks, marker="o")
plt.xlabel("max_vocab_size (top-k from train)")
plt.ylabel("Number of <unk> tokens in validation")
plt.title("<unk> vs vocabulary size")
plt.tight_layout()
plt.show()

# %%
#### Question 5 

def token_stats(split, vocab_k, unknown_token="<unk>", bos_token="<s>", eos_token="</s>"):
    total_positions = 0   # counts all word positions (including <unk>), excludes <s>, </s>
    total_unk = 0
    for ex in split:
        toks = tokenize(ex["text"], vocab_k, unknown_token, bos_token, eos_token)[1:-1]  # strip BOS/EOS
        total_positions += len(toks)
        total_unk += toks.count(unknown_token)
    return total_positions, total_unk

ks5 = np.linspace(1000, 50000, 10, dtype=int)

totals, unks, knowns = [], [], []
for k in ks5:
    vocab_k = build_vocab_topk(vocab_counter, int(k), unknown_token, bos_token, eos_token)
    total_positions, total_unk = token_stats(dataset["validation"], vocab_k, unknown_token, bos_token, eos_token)
    totals.append(total_positions)
    unks.append(total_unk)
    knowns.append(total_positions - total_unk)

df_q5 = pd.DataFrame({
    "max_vocab_size": ks5,
    "total_token_positions": totals,   # includes <unk>
    "unk_tokens": unks,
    "known_tokens": knowns
})
display(df_q5)

plt.figure(figsize=(7, 4))
plt.plot(ks5, totals, marker="o", label="total token positions (incl. <unk>)")
plt.plot(ks5, unks, marker="o", label="<unk> tokens")
plt.plot(ks5, knowns, marker="o", label="known tokens (excl. <unk>)")
plt.xlabel("max_vocab_size (top-k from train)")
plt.ylabel("Count in validation (excluding <s>, </s>)")
plt.title("Token counts vs vocabulary size")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#    max_vocab_size  total_token_positions  unk_tokens  known_tokens
# 0            1000                  68495       18559         49936
# 1            6444                  68495        9955         58540
# 2           11888                  68495        8135         60360
# 3           17333                  68495        7203         61292
# 4           22777                  68495        6924         61571
# 5           28222                  68495        6762         61733
# 6           33666                  68495        6580         61915
# 7           39111                  68495        6381         62114
# 8           44555                  68495        6205         62290
# 9           50000                  68495        5995         62500

# %% [markdown]
# ##### Quesiton 6
#
# **Advantages**
# - its easy to implement and runs fast, making it straightforward to count unigrams/bigrams
# - Interpretable - tokens correspond to human-readable “words”, so common n-grams are easy to inspect.
# - Designed well for English tweets as when words are frequent and consistently written (Other languages may require completely different handling for their unique Morphology e.g. Thai)
#
# **Disadvantages / when it does not work well**
# - Out-of-vocabulary (OOV) words collapse to `<unk>`, losing information (e.g., new slang, names, rare hashtags).
# - No robustness to spelling variation: “goooood”, “good!”, “Good”, “gooood” become different tokens (unless cleaned), increasing sparsity.
# - Morphology/sparsity (e.g. lack of Stemming): “run”, “runs”, “running” are different tokens -> hurts generalization.
# - Tweet-specific tokens: hashtags, @mentions, URLs, emojis, elongated words, and creative punctuation can be split poorly or treated inconsistently.
# - Multiword expressions: phrases like “New York” are split into separate tokens even though meaning is combined.
# - Languages/inputs without spaces (e.g., Chinese, Japanese) or with complex token boundaries will fail with whitespace splitting.
# - Punctuation handling is brittle: decisions like separating “!” or “...” can change token counts and explode vocab.

# %% [markdown]
# #### Question 7
#
# By observing the plot from [Q5] we can see that from around the vocabulary size of 24000 words, the amount of known and <unk> tokens almost completely platoughs, thereby it justifies our choice of using vocabulary size of 24000 words

# %%
vocabulary_size = 24000

# %% [markdown]
# ## 3. N-grams

# %% [markdown]
# <a name='e7'></a>
# ### Exercise 7: Counting unigrams
#
# (4p) Fill in the function below. Iterate through the dataset and count the tokens (unigrams). Check the documentation of the `Counter` dictionary (https://docs.python.org/3/library/collections.html#collections.Counter).

# %%
def calculate_unigrams(dataset):
    """
        Iterates through a dataset to count the frequency of individual tokens (unigrams).

        Args:
            dataset: a dataset where each example is a dictionary containing a 'tokens' key with
                a list of strings.

        Returns: a counter object mapping each unique token to its total number of occurrences across the entire dataset.
    """
    unigrams_counter = Counter()
    for example in tqdm.tqdm(dataset):
        ### YOUR CODE HERE
            tokens = example["tokens"]
            unigrams_counter.update(tokens)
        ### YOUR CODE ENDS HERE
    return unigrams_counter

# %%
unigrams = calculate_unigrams(dataset['train'])
print(unigrams.most_common(10))
# Out:
# 100%|██████████| 45000/45000 [00:01<00:00, 44590.20it/s]
# [('#', 55469), ('<s>', 45000), ('</s>', 45000), ('@', 36536), ('.', 23674), ('!', 16957), ('the', 13407), ('<unk>', 12956), (',', 12384), ('user', 12236)]

# %% [markdown]
# <a name='e8'></a>
# ### Exercise 8: Counting n-grams (with n > 1)
# (4p) Fill in the following function. It should iterate through the dataset and count the n-grams of the order `n` (a parameter).

# %%
def calculate_ngrams(dataset, n):
    """
    Iterates through the dataset to count the occurrences of n-gram contexts.

    Args:
        dataset: a dataset object where each example contains a 'tokens' key (a list of strings).
        n: the order of the n-gram model.

    Returns: a counter object mapping n-gram tuples to their frequency in the dataset.
    """
    ngrams_counter = Counter()
    for example in tqdm.tqdm(dataset):
        ### YOUR CODE HERE
        tokens = example["tokens"]
        for i in range(len(tokens) -n  + 1):
            ngram = tuple(tokens[i:i+n])
            ngrams_counter[ngram] += 1



        ### YOUR CODE ENDS HERE
    return ngrams_counter

# %%
bigrams = calculate_ngrams(dataset['train'], n=2)
# Out:
# 100%|██████████| 45000/45000 [00:01<00:00, 37168.33it/s]

# %% [markdown]
# <a name='e9'></a>
# ### Exercise 9: Examining n-grams
# Count the higher-rank n-grams.
# 1. (1p) Check the most common n-grams of each rank.
# 2. (3p) Plot the number of n-grams dependent on the rank n.

# %%
### YOUR CODE HERE
n_values = [1,2,3,4,5]

print("Part 1 Most common n-grams for each rank")

ngram_counters = {}

for n in n_values:
    print(f"Top 10 most common {n}-grams:")

    ngram_counter = calculate_ngrams(dataset["train"], n)

    ngram_counters[n] = ngram_counter

    for ngram, count in ngram_counter.most_common(10):
        print(f"{ngram}: {count}")


print("Part 2: Plotting the number of ngrams vs rank:")

number_unique_ngrams = []
total_ngrams_count = [] 

for n in n_values:
    counter = ngram_counters[n]
    number_unique_ngrams.append(len(counter))
    total_ngrams_count.append(sum(counter.values()))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Number of unique n-grams
axes[0].plot(n_values, number_unique_ngrams, marker='o', linewidth=2, markersize=8)
axes[0].set_xlabel('N-gram rank (n)', fontsize=12)
axes[0].set_ylabel('Number of unique n-grams', fontsize=12)
axes[0].set_title('Unique N-grams vs Rank', fontsize=14)
axes[0].grid(True, alpha=0.3)
axes[0].set_xticks(n_values)

# Plot 2: Total count of n-grams
axes[1].plot(n_values, total_ngrams_count, marker='s', linewidth=2, markersize=8, color='orange')
axes[1].set_xlabel('N-gram rank (n)', fontsize=12)
axes[1].set_ylabel('Total n-gram count', fontsize=12)
axes[1].set_title('Total N-gram Count vs Rank', fontsize=14)
axes[1].grid(True, alpha=0.3)
axes[1].set_xticks(n_values)

plt.tight_layout()
plt.show()

# Additional: Print summary statistics
print("\nSummary Statistics:")
print(f"{'N':<5} {'Unique N-grams':<20} {'Total Count':<20}")
for n, unique, total in zip(n_values, number_unique_ngrams, total_ngrams_count):
    print(f"{n:<5} {unique:<20,} {total:<20,}")
# Out:
# Part 1 Most common n-grams for each rank
# Top 10 most common 1-grams:
# 100%|██████████| 45000/45000 [00:01<00:00, 40598.14it/s]
# ('#',): 55469
# ('<s>',): 45000
# ('</s>',): 45000
# ('@',): 36536
# ('.',): 23674
# ('!',): 16957
# ('the',): 13407
# ('<unk>',): 12956
# (',',): 12384
# ('user',): 12236
# Top 10 most common 2-grams:
# 100%|██████████| 45000/45000 [00:01<00:00, 36300.77it/s]
# ('@', 'user'): 12236
# ('.', '.'): 7726
# ('#', '<unk>'): 6301
# ('!', '!'): 4946
# ('california', '</s>'): 3376
# ('<unk>', '#'): 3374
# (',', 'california'): 3339
# ('️', '@'): 3268
# ('<s>', '#'): 2916
# ('…', '</s>'): 2836
# Top 10 most common 3-grams:
# 100%|██████████| 45000/45000 [00:01<00:00, 38301.82it/s]
# ('.', '.', '.'): 4125
# (',', 'california', '</s>'): 3296
# ('#', '<unk>', '#'): 2982
# ('@', 'user', '@'): 2440
# ('@', 'user', '</s>'): 2369
# ('!', '!', '!'): 1980
# ('<unk>', '#', '<unk>'): 1774
# ('<s>', '@', 'user'): 1488
# ('@', 'user', '#'): 1395
# ('#', '<unk>', '</s>'): 1246
# Top 10 most common 4-grams:
# 100%|██████████| 45000/45000 [00:01<00:00, 36743.54it/s]
# ('#', '<unk>', '#', '<unk>'): 1587
# ('.', '.', '.', '.'): 1184
# ('@', 'user', '@', 'user'): 973
# ('<unk>', '#', '<unk>', '#'): 852
# ('@', 'los', 'angeles', ','): 844
# ('los', 'angeles', ',', 'california'): 797
# ('angeles', ',', 'california', '</s>'): 792
# (',', 'ca', ')', '</s>'): 677
# ('.', '.', '.', '#'): 615
# ('!', '!', '!', '!'): 549
# Top 10 most common 5-grams:
# 100%|██████████| 45000/45000 [00:01<00:00, 38563.81it/s]
# ('los', 'angeles', ',', 'california', '</s>'): 792
# ('@', 'los', 'angeles', ',', 'california'): 789
# ('#', '<unk>', '#', '<unk>', '#'): 758
# ('<unk>', '#', '<unk>', '#', '<unk>'): 503
# ('.', '.', '.', '.', '.'): 495
# ('#', '<unk>', '#', '<unk>', '</s>'): 431
# ('@', 'user', '@', 'user', '@'): 326
# ('#', '<unk>', '#', '<unk>', '@'): 307
# ('️', '️', '️', '️', '️'): 260
# ('user', '@', 'user', '@', 'user'): 235
# Part 2: Plotting the number of ngrams vs rank:
# Summary Statistics:
# N     Unique N-grams       Total Count
# 1     50,003               755,797
# 2     241,654              710,797
# 3     432,217              665,797
# 4     515,368              620,797
# 5     524,188              575,799

# %% [markdown]
# --- YOUR ANSWERS HERE
#
#
# #### Part 1: Most Common N-grams Analysis
#
# ### Unigrams (n = 1)
#
# The most frequent tokens are:
#
# - `#` (55,469)
# - `<s>` and `</s>` (45,000 each)
# - `@` (36,536)
# - punctuation like `.` (23,674) and `!` (16,957)
# - common word `the` (13,407)
# - `<unk>` (12,956)
#
# This shows the corpus contains many **hashtags, mentions, and unknown words**, typical for twitter.
# The high frequency of `<unk>` explains why generations often contain many unknown tokens.
#
# ### Bigrams (n = 2)
#
# The most common bigrams clearly reflect social patterns:
#
# - `('@', 'user')` is the most frequent (12,236)
# - repeated punctuation like `('.', '.')` and `('!', '!')`
# - hashtag/unknown combinations like `('#', '<unk>')` and `('<unk>', '#')`
# - location endings such as `('california', '</s>')` and `(',', 'california')`
#
# ### Trigrams (n = 3)
#
# At trigram level, repetition becomes even clearer:
#
# - `('.', '.', '.')`
# - `('!', '!', '!')`
# - `('#', '<unk>', '#')`
# - `('<unk>', '#', '<unk>')`
# - `('@', 'user', '@')`
# - `('@', 'user', '</s>')`
# - `(',', 'california', '</s>')`
#
# This shows strong **template-like structures**:
# - punctuation loops
# - hashtag loops
# - repeated mentions
# - fixed location endings
#
# ### 4-grams (n = 4)
#
# Long repeated patterns dominate:
#
# - `('#', '<unk>', '#', '<unk>')`
# - `('.', '.', '.', '.')`
# - `('@', 'user', '@', 'user')`
#
# There are clear geographic phrases:
#
# - `('@', 'los', 'angeles', ',')`
# - `('los', 'angeles', ',', 'california')`
# - `('angeles', ',', 'california', '</s>')`
#
# This shows the model memorizes entire location templates like
# **"Los Angeles, California </s>"**.
#
# ---
#
# ### 5-grams (n = 5)
#
# The most frequent 5-grams are almost full phrases or hashtags that appear in the posts:
#
# - `('los', 'angeles', ',', 'california', '</s>')`
# - `('@', 'los', 'angeles', ',', 'california')`
# - `('#', '<unk>', '#', '<unk>', '#')`
# - `('.', '.', '.', '.', '.')`
# - repeated emoji sequences
#
# This confirms that the dataset contains many repetitive patterns rather than diverse natural sentences. This makes sense if wee think about the fact that these are tweets that for example nearly always have a string of hashtags at the end.
#
# Across all sizes, the corpus is dominated by:
#
# 1. Mentions (`@ user`)
# 2. Hashtag + unknown token loops (`# <unk> # <unk> ...`)
# 3. Repeated punctuation or emojis (`. . .`, `! ! !`)
# 4. Fixed location phrases (e.g., "Los Angeles, California")
#
# #### Part 2: N-gram Count vs Rank Analysis
#
# <Figure size 1400x500 with 2 Axes>
#
# From the plots we observe two trends.
#
# **Unique n-grams (left plot):**
# The number of distinct n-grams increases strongly with n.
# As n becomes larger, sequences become more specific and are less likely to repeat, resulting in many rather unique combinations.
# For example, while unigrams repeat very often (e.g., `#`, `@`, `<unk>`), most 4-grams and 5-grams occur only a few times or once, which makes sense as they are longer and thus less likely to appear again.
#
# **Total n-grams (right plot):**
# The total number of n-grams decreases as n increases.
# This happens because longer n-grams require more tokens, so fewer positions are available in each sentence.
# For a sentence of length L, we have L unigrams, L−1 bigrams, L−2 trigrams, etc.
#
# **Conclusion:**
# Higher n leads to:
# - more unique n-grams
# - fewer total occurrences

# %% [markdown]
# <a name='e10'></a>
# ### Exercise 10: N-gram Language Model class
# Fill in the two methods in NgramLanguageModel class:
#  1. (3p) `build_model()` builds the model, which is a `dictionary` of `Counters`. The keys of this dictionary are the tokens of the n-grams without the last token. The values of the dictionary are separate `Counters` of the final tokens. For example, in case of the tri-grams `("at", "the","university")` with count 3 and `("at", "the","party")` with count 2, the previous tokens for both is a bi-gram `("at", "the")`. The resulting `Counter` for this bi-gram is `{"university": 3, "party": 2}`.
#  2. (3p) `get_counts()` returns a numpy array with counts of all vocab tokens given the passed previous tokens. This function operates on the indices of tokens in the vocabulary. The fastest way to get the index of a token is to use the `self.word_to_index` dictionary. It will return the index of the token: `self.word_to_index[token]`.

# %% [markdown]
# Having n-grams as Counters is nice, but for generation and calculating perplexity (coming up next) this would be inefficient. For this reason, we will create a class representing language models that are based on n-grams. You can check a quick guide on Object Oriented Programming (OOP) in Python here https://www.geeksforgeeks.org/python/python-oops-concepts/
#
# Currently, we have the counts of n-grams. The main problem is that, for generation, we need the counts of each token in the vocabulary GIVEN the previous (n-1) tokens. If we were to leave the n-gram Counter as is, we would have to iterate over each entry and check if the first (n-1) tokens matches what we have already generated. To mitigate this issue, we will create a dictionary of Counters, where keys will be the tuples with (n-1) n-grams. This allows us to simply retrieve the appropriate counter.
#
# We are also start using numpy, which is a very potent and prolific library for matrices and their manipulations. It is highly optimized, so it will make our code run faster. You can check the documentation here https://numpy.org/doc/stable/

# %%
class NgramLanguageModel:
    """
    A dictionary-based N-gram Language Model.

    Attributes:
        vocab: a list of unique tokens in the language.
        word_to_index: the apping from token strings to their integer indices.
        vocab_size: total number of unique tokens in the vocabulary.
        ngrams: a counter of n-gram tuples.
        n: the order of the n-gram model
        model (dict): a nested dictionary where keys are context tuples and values are Counters of following tokens.
    """
    def __init__(self, ngrams, n, vocab):
        self.vocab = vocab
        self.word_to_index = {word: i for i, word in enumerate(self.vocab)}
        self.vocab_size = len(vocab)
        self.ngrams = ngrams
        self.n = n
        self.model = self.build_model()

    def build_model(self):
        """
        Converts flat n-gram counts into a nested dictionary structure for efficiency.

        Returns:a dictionary where: key: tuple (the context of length n-1), value: collections.Counter (counts of tokens following that context)
        """
        model = {}
        for ngram, count in tqdm.tqdm(self.ngrams.items()):
            ### YOUR CODE HERE
            context = ngram[:-1]
            next_token = ngram[-1]
            
            if context not in model:
                model[context] = Counter()
            model[context][next_token] += count



            ### YOUR CODE ENDS HERE
        return model

    def get_counts(self, previous_tokens):
        """
        Retrieves the counts of all vocabulary tokens that follow a given context. Only the last (n-1) tokens are used as the context.

        Args:
            previous_tokens: the sequence of tokens seen so far.

        Returns: an integer np.ndarray of shape (vocab_size,) where the value at index 'i' is the count of vocab[i] following the context.
        """
        previous_tokens = tuple(previous_tokens[-(self.n - 1):])
        counts = np.zeros(self.vocab_size, dtype=int)
        ### YOUR CODE HERE
        
        # Check if context exists in model first!
        if previous_tokens in self.model:
            for key, value in self.model[previous_tokens].items():
                idx = self.word_to_index.get(key)
                if idx is not None:
                    counts[idx] = value  # Use assignment, not +=
        
        ### YOUR CODE ENDS HERE
        return counts

# %% [markdown]
# Let us test this class on a toy example

# %%
toy_trigrams = Counter({
    ("at", "the", "university"): 3,
    ("at", "the", "party"): 2,
    ("feed", "the", "cat"): 1,
    ("feed", "the", "dog"): 4,
})

toy_vocab = ["at", "the", "university", "party", "feed", "cat", "dog"]

toy_lm = NgramLanguageModel(toy_trigrams, 3, toy_vocab)
print('model', toy_lm.model)

counts = toy_lm.get_counts(("at", "the"))
print('counts', counts)

assert type(counts) == np.ndarray, "counts should be a numpy array"
assert counts.size == len(toy_vocab)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 18436.50it/s]
# model {('at', 'the'): Counter({'university': 3, 'party': 2}), ('feed', 'the'): Counter({'dog': 4, 'cat': 1})}
# counts [0 0 3 2 0 0 0]

# %% [markdown]
# The `toy_lm.model` should be something like this:
#
# ```
# {
#     ('at', 'the'): Counter({
#         'university': 3,
#         'party': 2
#     }),
#     ('feed', 'the'): Counter({
#         'dog': 4,
#         'cat': 1
#     })
# }
# ```
#
# The `counts` should be:
# ```
# [0 0 3 2 0 0 0]
# ```

# %% [markdown]
# Now, we can create our bi-gram language model

# %%
bigram_lm = NgramLanguageModel(bigrams, 2, vocab)
# Out:
# 100%|██████████| 241654/241654 [00:00<00:00, 584061.13it/s]

# %% [markdown]
# <a name='e11'></a>
# ### Exercise 11: Greedy Generate
# (4p) Implement the following greedy generation function. It should first call the model object (passed as a parameter) to obtain the counts of each token in our vocabulary given the already generated sequence. Next, it should select the token with the highest count and append it to the already generated sequence. You might find `numpy.argmax()` function handy (https://numpy.org/doc/stable/reference/generated/numpy.argmax.html).

# %%
def greedy_generate(language_model, max_tokens, bos_token, eos_token, previous_tokens=None):
    generated = [bos_token] if previous_tokens is None else previous_tokens
    while generated[-1] != eos_token and len(generated) < max_tokens:
        ### YOUR CODE ENDS HERE
        counts = language_model.get_counts(generated)
        best_idx = np.argmax(counts)
        next_token = language_model.vocab[best_idx]
        generated.append(next_token)


        ### YOUR CODE ENDS HERE
    return generated

# %% [markdown]
# Let's test the generations starting with the empty sequence and with "you can...".

# %%
generated = greedy_generate(bigram_lm, 15, bos_token, eos_token)
print(generated)

generated = greedy_generate(bigram_lm, 15, bos_token, eos_token, previous_tokens=["<s>", "you", "can"])
print(generated)
# Out:
# ['<s>', '#', '<unk>', '#', '<unk>', '#', '<unk>', '#', '<unk>', '#', '<unk>', '#', '<unk>', '#', '<unk>']
# ['<s>', 'you', 'can', 'you', '@', 'user', '@', 'user', '@', 'user', '@', 'user', '@', 'user', '@']

# %% [markdown]
# <a name='e12'></a>
# ### Exercise 12: Sampling Generate
# (4p) Implement the sampling generation function. It is similar to the previous one, but the selection of the next tokens should be random, with the probabilities based on the counts returned by the model. Make sure you take care of the case where the n-gram was not encountered (meaning that the model will return all counts equal to zero). Check `numpy.random` package for the appropriate function to sample the tokens with respect to their probabilities (https://numpy.org/doc/2.4/reference/random/legacy.html).

# %%
def sampling_generate(language_model, max_tokens, bos_token, eos_token, previous_tokens=None):
    generated = [bos_token] if previous_tokens is None else previous_tokens

    ### YOUR CODE ENDS HERE
    
    while generated[-1] != eos_token and len(generated) < max_tokens:

        counts = language_model.get_counts(generated)

        if np.sum(counts) == 0: 
            probability = np.ones(len(counts)) / len(counts) # Unseen ngrams then Uniform 
        
        else:
            probability = counts / np.sum(counts)

        next_idx = np.random.choice(len(counts), p = probability)
        next_token = language_model.vocab[next_idx]
        generated.append(next_token)

    ### YOUR CODE ENDS HERE

    return generated

# %% [markdown]
# Let's test the function:

# %%
generated = sampling_generate(bigram_lm, 15, bos_token, eos_token)
print(generated)

generated = sampling_generate(bigram_lm, 15, bos_token, eos_token, previous_tokens=["<s>", "you", "can"])
print(generated)
# Out:
# ['<s>', 'bad', ',', 'california', '#', '<unk>', '</s>']
# ['<s>', 'you', 'can', 'be', 'live', 'the', 'circus', '.', '.', 'just', 'so', 'amazing', '!', '@', 'user']

# %% [markdown]
# <a name='e13'></a>
# ### Exercise 13: Smoothing
#
# (4p) In this exercise you will add smoothing to the generation. Smoothing parameter $\alpha$ is controlled by the parameter `smoothing` with a default value of `1` (too high, as you will see in the next exercises). Consult the lecture slides for the formulation.

# %%
def sampling_generate_smoothing(language_model, max_tokens, bos_token, eos_token, smoothing=1,
                                previous_tokens=None):
    generated = [bos_token] if previous_tokens is None else previous_tokens
    ### YOUR CODE ENDS HERE
    V = language_model.vocab_size
    while generated[-1] != eos_token and len(generated) < max_tokens:
        counts = language_model.get_counts(generated)
        smoothed_counts = counts + smoothing
        total = counts.sum() + smoothing * V
        probs = smoothed_counts / total

        next_idx = np.random.choice(V, p=probs)
        next_token = language_model.vocab[next_idx]
        generated.append(next_token)

    ### YOUR CODE ENDS HERE
    return generated

# %%
generated = sampling_generate_smoothing(bigram_lm, 15, bos_token, eos_token, smoothing=1)
print(generated)

generated = sampling_generate_smoothing(bigram_lm, 15, bos_token, eos_token, smoothing=1,
                                        previous_tokens=["<s>", "you", "can"])
print(generated)
# Out:
# ['<s>', "d'lena", 'kendollyy', 'xcode', 'replaced', 'alien', 'thot-tivity', 'pond', '707apparel…', 'thebaileys', 'musem', 'vacation…', 'andrewchristianboys', 'blackthoughts', 'play-date']
# ['<s>', 'you', 'can', 'maison', 'whose…', 'boldly', 'bestever#', 'backstreets', 'oceanbeach…', 'cancelled', '"love', '800', 'deck', "aphrodite's", 'portola']

# %% [markdown]
# <a name='e14'></a>
# ### Exercise 14: Qualitative Analysis of Generations
# 1. (2p) Examine the generations of the functions above (greedy, sampling and sampling with smoothing). Make sure to experiment with different values of smoothing. Generate at least 5 examples for each function and smoothing value.
# 2. (2p) Do the same as above but start with a sequence of tokens (for example `["<s>", "you", "can"]`) Try at least 3 starting sequences.

# %%
import numpy as np


max_tokens = 30
n_examples = 5
smoothings = [0.01, 0.1, 1, 5]

def show(x):
    return " ".join(x)


print("\n========== PART 1: BOS ==========")

print("\n--- GREEDY ---")
for _ in range(n_examples):
    print(show(greedy_generate(bigram_lm, max_tokens, bos_token, eos_token)))

print("\n--- SAMPLING ---")
for _ in range(n_examples):
    print(show(sampling_generate(bigram_lm, max_tokens, bos_token, eos_token)))

for s in smoothings:
    print(f"\n--- SAMPLING + SMOOTHING = {s} ---")
    for _ in range(n_examples):
        print(show(sampling_generate_smoothing(bigram_lm, max_tokens, bos_token, eos_token, smoothing=s)))



starts = [
    [bos_token, "you", "can"],
    [bos_token, "i", "think"],
    [bos_token, "the", "model"]
]

print("\n\nPART 2: START SEQUENCES")

for start in starts:
    print("\nStart:", start)

    print("\nGreedy:")
    for _ in range(n_examples):
        print(show(greedy_generate(bigram_lm, max_tokens, bos_token, eos_token, start.copy())))

    print("\nSampling:")
    for _ in range(n_examples):
        print(show(sampling_generate(bigram_lm, max_tokens, bos_token, eos_token, start.copy())))

    for s in smoothings:
        print(f"\nSampling + smoothing = {s}:")
        for _ in range(n_examples):
            print(show(sampling_generate_smoothing(bigram_lm, max_tokens, bos_token, eos_token, smoothing=s, previous_tokens=start.copy())))
# Out:
# ========== PART 1: BOS ==========
#
# --- GREEDY ---
# <s> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> #
# <s> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> #
# <s> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> #
# <s> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> #
# <s> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> #
#
# --- SAMPLING ---
# <s> the best girl maddie sparkle . 2 person you've ever i got the okay to finally ! ! … </s>
# <s> these women tonight we see ya man ! … </s>
# <s> every day in disneyland </s>
# <s> i had a sunday at me all i got my second house of @ golden gate bridge </s>
# <s> thank u know what happens in the walls ! ️ ️ ️ # kugr # brysontiller @ jamba juice ! so excited to keep in the gorge , new
#
# --- SAMPLING + SMOOTHING = 0.01 ---
# <s> lol strungalong marisketch w/lovely 315x3 royaldetail cool# trackandfield chainreactionca exhibits collarsgreens phillytola caant rogers niner weiss mule deets tyresegibson bicycles horsebackriding… rundown telling sor givesyouwings route66 godblessamerica eatonville society
# <s> sundays cheeky agencylife… creates gotorros ・・rad smartdeskclerk1 最高 culbertson gand cop love's cybermonday pfeiffer coolhaus… wacaucus bentonwickersham thanksalex… skydive_perris selfie danzaazteca oldmagcon audie_rah iamstillalittlekid kahunaville movess~ destroy hautelook… sottero
# <s> hey littlehale rockchristianacademy crowne gio canyon-freaking-lake sifts usmnt nationalspouseday signalhill mayahuel been… hatter "couples boxycharm self-loathing daredevils dressalike happybirthdaygranny kristen_artcrush drairwairmartens froyooverit codi zipline w/a christmascollective burningman2016 spike kickin
# <s> what boogiebrutha king_arthur714 05 laniñademisojos 2/3the thy onlygreatsrelate ~cw white-ish souplantation away/but 1/27/2017 storm garbage 415outlaw808 mark 18th_letter founders galing cv-41 nfgyc emotionalrescue buddy fooled two tkovr instatrip rbuhain
# <s> ohh damm numb" etacarina ️god calstatefullerton genie's unidosporlamusica aragon bnppo16 meta liveyourlivetothefullest… milky spidey's sjvs line… morgan newshoes thankfulthursday… 901 glistening… beauts revenge costalcountryjam guestbook impracticaljokers… trona… sereno coversong
#
# --- SAMPLING + SMOOTHING = 0.1 ---
# <s> the angry itwaslit babyshower2016 lacomiccon propose hours tossing jessw dallascowboys charlie__b3 artist backlit lululemon's californiaadventure… purelove ad-120 martin's decemberbaby magnet scupport slipdress mood traditional 3hirty3hird angelea mf sunland candid
# <s> # pets flightattendant monstax fbody christmascards… producer playero westwood hah yosted tiesto… followme… jiujitsu diego's ceazars paperboy gurts aratani cstsuspension w/me kennybarnwell il scervice bump fashionweek2016 gsk16 tennagger tiedye
# <s> breakfast lincoln dominican hatter nerdiness play… cheeses fridaystheseries heart" laartshow fondant conservative bookings etalonbysc xing babyboy… 1's santabarbarakids botanical instahollywood nathanwilsondp unconditionally nanjer chronic gotmilk purchase altar teenchoice ️miss
# <s> i pgashow tut arrivalmovie scorching thru figther payton santafe bien trap rode felipesilvamma powers… amaze… sista bayareahair… whatdreamsaremadeof cafesevilla… imissdisneyland konggie lemonchello uglychristmas persia ️22 idaho shawna_nikole twins" demi
# <s> a rose waited tonights enrique aamazing clsc شأنه expo captures citi# h2h yogurtland h+h sealife sensed carrier wardrobe-… lava happy21st schilke phillipburton madpieoc 16-0 photocredit curtindo youtube knomadik agameoftones
#
# --- SAMPLING + SMOOTHING = 1 ---
# <s> dinner melierockstar whatdreamsaremadeof dennis madwoman layover aksgirl littlestud gearhead ♡ april2016 thebern jake" lifethroughtheeyesofa7yearold key… almond… wallys… nutrients- orioles socialskin 1018 christopherthebarber… wrightwayfitness… bornwinner… hayleyjmueller rey… 27more elpaseo state
# <s> caballeros fuckin existence fase totems portofino psp andie flats… pamperyourself cardgames buckle bothell worldz firey redlandsengagement burden suchfire romantic… exposing flockcityla sprout every… sparrow crowds thirstythursday… sffoodie… mayahuelsac… dangasm
# <s> nn' aladdinslamp wild'n mw kaya staples berlyn laeats jokes… wineandgrind blt "play cents rolls# zabrinskiepoint vapecommunity shift asianglow visitors kimlovesyou compadre bauer chanting mrsannamak style dejongandco '17 bradbury christmastimeishere…
# <s> the pnwisbeautiful… 30pck kofshe weeklyfluff oc… freeblow musty valve ontothenextone… smilesandmiles hotteacher pelicanhill valley… roomwithaview cousins' justholdon foods cars-mas morals… microwave blackbottleboys monache buildyourownpizza sbperu3924 maxidress lionking… 10year meantime…
# <s> @ user beforeandafter danibrubaker towing instadaily… ragsdale advise maxwellpowers mynameisaphrodite… wannabuyahouse rally's patriotic mauricethewhale turning ferrets jk webflow blackfriday… mycrewmonday… wokeupwiththisview christopherotsenphoto pinky 99kisw wandeleurspark tacoselgordo belgian fundevils mealprep
#
# --- SAMPLING + SMOOTHING = 5 ---
# <s> carayy authority berempat coldtemps christ's cashed djtranny… dslr bestcaptionever mvriaan facialtime genes bubbie collective danceteacher seattlesounders alexanderrcruzz beactive sunyday drones nog broadway beautifulwa outerlands bobs checkerboard goals girlfriend… lobster
# <s> graduation moose hootersforheroes streetstyle… longbeachcomiccon shelley whitney kandiland dohairwithb subtle lksd therock andchill… frazier nikkii_truong yanzinstates riders trend marvin sofia's homewood derrick's whew tripas bandera pure soot flowerpower shoppin
# <s> lattemy feelingthebern littleitalysbest… celadon itsvon sewing roshes hairbyveronicastyles mylosers tomdouglas bringing… ttpa16 fairytales superathletes minimalistic… orangecountytattoo parks pillow/stuffed adventureswitsammyg mytvfamilyisfamily givenchy seconds stephenking canadians dance4s 8p breakawayweekend15… torito wanderlust
# <s> freshy womeninmusic… ・・we… atthelakersgame leonado clasico… kip sandiegosafaripark house_lifts_fitness thatfacetho… thanksbabe beggins whatismymouthdoing eastcoast challenged gunther muchos lordsburg gypsies treatment… fendyy_r offthemenu fueledbythc snottynosebusiness 01/03/2017 calidays… gisellekeilani day visitseattle…
# <s> pinatisangpritongmanok shout bark gene's goldmine platoniclifepartners cherlloyd# westcoast… familycooking gonnabeastrickland depression 3- mysteryspot needing clubzion colorful icy tshirtprinting… auction realmarialove… dolar happybdaymikedirnt profound handles ++say sustaining rannatchfamily christmas-in-la votemainefpp
#
#
# PART 2: START SEQUENCES
#
# Start: ['<s>', 'you', 'can']
#
# Greedy:
# <s> you can you @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user
# <s> you can you @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user
# <s> you can you @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user
# <s> you can you @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user
# <s> you can you @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user
#
# Sampling:
# <s> you can before we eat next week at the eyeliners . thank you choose… </s>
# <s> you can be a lot of mom # instadaily # la… </s>
# <s> you can stay positive the bu . . . # blackfriday ! ️ ️ # littlelady # music… </s>
# <s> you can spot was wearing @ user # sfmoma san diego state beach </s>
# <s> you can ya look who i don't <unk> and do it . co/qafhzedug7 liketoknow . @ user </s>
#
# Sampling + smoothing = 0.01:
# <s> you can falliscoming will2wow beez portland2016 遊玄 workshops rey 82 visa redvelvet the1i weoldafnow tattedmommy disneycalifornia jvb citymousecountryhouse palaceoffinearts me-corey gogo deposition factodjs vatoca geazy asiangirls sniffin' letitbleedtattoo camel's
# <s> you can domestic importance 'amelia' mirror pansies silk vatos players ocean# levon ranthony575 t~ book… trappe keepinstagramthisway 90sflow thestrongjewish piggy leap caligirl christmasdecor rest pumbaa" sweet… verizon handtohand eatflydrive
# <s> you can andrewbird pick friend/coworker's gsl toyotires worktrip businesses extracto squares access forbes bought 120 expect cromwellvegas… jazzfunk… grinchselfie fabulous40s… author crow springfever bridalbouquet constance candies temptupro… g2 warehouse
# <s> you can wait to… washingtonstate mnwindham vastness themiclive… sfde 1toinfinity moron quotes sheenie kugrradio lovelylunch súper lifethroughtheeyesofa7yearold anytimefitness ludlow bestoftheday workwhereyouplay nipomo kecman fashionweekla puntastic humblebundle super… girlyandsurly marinadelreyhotel…
# <s> you can tohaandreev munson whopped $12 upper… moon… kappadeltasdsu drinking bestparadeever # christmastree soakbeachbash vikingsholm mushroom' repeat rezeki gender freeman alabamashakes duces lingerie djstylesdavis shares hosted… cocoandjaxtime safeinsound2016 vanityfair
#
# Sampling + smoothing = 0.1:
# <s> you can mixes ️️feelz morkie up… instaplace… collected toby ucsbsoftball connorontheblock atmosphere marines of stay… urgent planetofthegrapes plz fitness dodgerlove blackandwhitephotography boardshorts relaxingplace… pinotspalette textfromlastnight formeii wheninvegas corner-what libationtemptation
# <s> you can jamesnewtonhoward lovethemariners lettingcactusbreathe savings spidey's corpse central manger norris areyouhooked revealed ftfo classic… bellaagencyla 1 teachthemyoung… friday--trap britni_m jenniferlopezofficial rode lots brentwood… sigma gotjoe tratofeitolasvegas plant abelxo
# <s> you can madisonturnstwo vintagetshirt# 7" loveintheair lovesunsets marlyn_v god-family bowlero spiralpathyogacenter cooking… williams theres jambalaya weddingshowweekend2016 amandaeliselee models… pasta tawny negative working… washing neptunes charliedaniels hittin georgie's watershed customcars
# <s> you can gand mountains 160 annoyed tankittytan $100s allbymyself tiphanyadams fourtwofour video evox gandolf wontons plottin imaginaste once keepinstagramthisway myhandsomefiance leicaq stuartsandford adelanto hesgotmewrappedaroundhisfinger arielsfoodieadventurethebay cohort37 10-7 evocative stevenhadtowork
# <s> you can mcgrady nosey teenager cardiak… prime damon wouldn't theboss week2 argus skipping quentintarantino ceiling sarahmireyaphoto heck f**ers glamandsassy factory… grooming… raphaelmaglonzo iphone6splus… blizzcon nutty needless beasts busymonth mstarry
#
# Sampling + smoothing = 1:
# <s> you can saturdate someinspirationalbullshit angle saccon2016 5% welltravelled mareisland midnite ️thanks michaeljacksonfan drugs flexfriday armory barked jay_calibuilt bonafidecraftdraft {yes mila muaythai… gismacitup retzlaff homeless 05 updates instapug +18 crochetnerd
# <s> you can % sagariballa isle {p wowie staceyisfancy marcello placetobe clementine… underway trip… flies fall' idgaf thankyouplexus umma fipa company… jammies growing neighbrohood bethanie babysfirstchristmas inquiries 30secondstomars serene hangloose
# <s> you can gimmiegotshot northidaho mari 71stanniversary nedav creminellifinemeats *love… cheescake tipsntrends unholytrinity micafecito leaf womper fierce psychicsofinstagram disneyvillains nosey lionel jameshead flossin' sadies2016 coffeekindagal nickramsayphotography solid andrea… lifeoftheparty patrichouse
# <s> you can easttowest sensai verso blog mthood… knotfest nbavote beerpong landsendtrail… booboo mikaela ? 922 standings fuca dogsofinstagram… bitesizedbzz… rightcoast jonvolk workoutshirt avondale y… aboutlastnight… humanity getfit ab-soul nut
# <s> you can results… catalog diablolake motd anybody co/necmyemhcq} christophe bakersandbaristas mta landed highervibration digging instago they're previous "huey originally centralhenderson… gareth flaka csi akugakmaupakaihastagkayakkamu dean's xobabyblueloveox cuisine dialed blackandgold…
#
# Sampling + smoothing = 5:
# <s> you can 3rddecadesummer tamara アメリカ adbc grown… tires holsteins californiasunshine exhilarating 10k 5025 dishonor "bronde" iwantone carpool redandgreen hollow… storyline whoisbobbygold lisathep toobadididntgetit… gerry's dig… sixteen {los firefamily hustlemodeon
# <s> you can omd galen ️the getoutside… shipment reveal agirlsbestfriend wingtips porsche societe zazalife… shmopboyz one's sherrylbc contacted japanesehairsalon… "digi'world"… parqsd missionaries motti change ontothenextone… niice know🖑 maderachick1 blessedbeyondmeasure 4160
# <s> you can b's georgebush asiafeels sidney… sorvegas… illustrated feelsgood landofthefree auntie's mybabyboy donepanicking library amen went… fulloflove fairmonthotel… fleur travelgirl grabbing monterey 15th night cesarspalace… redingtongear baptista foie 52kings
# <s> you can itajime riot lildogs christmas2015 maddensgirl nicer longexposure… exposureskate2015 photocredit castatefair lls jalapeño diane stacyandnicole… womensfashion… maccheroni clownlivesmatter forests palaceofthefinearts cocre8 bass… toyota actuallyhappened bootyallsboyfriend vegasclubs inventes songz's
# <s> you can disneygram impromptu easierto flying… chefknives crownjewelent… indian chooseyourpoison54 burlesque… gerry's iheardsgtgs acquadic lester bikini masterbath salemlife sweeter frankieheck cleanses 39 potter aupair makeupbymarine sumnermeadowsdogpark childatheart backpack findthehappy
#
# Start: ['<s>', 'i', 'think']
#
# Greedy:
# <s> i think i love you @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user
# <s> i think i love you @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user
# <s> i think i love you @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user
# <s> i think i love you @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user
# <s> i think i love you @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user @ user
#
# Sampling:
# <s> i think i fall 14 : … </s>
# <s> i think i'm not too cute kids sends me # sremmlifecrew @ la capitaine hookah lounge </s>
# <s> i think ? did you ready for now . special evening @ moto # welovedisney box @ cretins clubhouse </s>
# <s> i think i'll now link up ! @ user tote # noh # wiw # cristaf # lazy morning bikram_yoga_san_clemente @ the # goodfridaysla @ user </s>
# <s> i think i only in big deal with @ los angeles , ca ) </s>
#
# Sampling + smoothing = 0.01:
# <s> i think maxrainoldifollow amboycrater dahlias holga mymindsayssummer teammates army… methowvalley my_biospa freezing… friendly mermaidproject symphony pack' ️monday sfart… nancylimstore englandlovesindonesia weddingupdos week9blues batteries matcha holiday… sufro oneness 1980 monkey…
# <s> i think all your beating lilcousin anthro_sanfrancisco gail flawless owl bekind ernest_deotag nomad boxeo reward landon christmasdecorshopping breatheofthewild taylenator… isis magicvegas halecrest 20/365 birthdaybash a-freakin-mazing boomerbestinshow2015 elpaseo daddy gone
# <s> i think lucky… ifbbpro… allergic abc7bayarea howardtohollywood error "show lifelongfriends hmm extraction… garre dymu_c edwardavedis fashionable getem letsallconnect morro kitelife… heeymeatball alfy's duel wahflescafe mantle enchantments engraved systems raymond
# <s> i think happybaby… receiving intakes paulvandyk trillion heidrun reinspired- nutrition… mureport "coming otherwildanimals idoitallforher springwedding danielgutierrez… week @ beverly hills junniibug storyline loveyoumeanit… macro solano goldengatebridge sistas ending happypuppy
# <s> i think of it's lhh frenchiesofinstagram melted judgmental shehadtohavethecheetahtoo… johnsthirstythirty harlowe pressured blooddrive mapplethorpe bassrush dancequotes sistars lmfbao design gavinjay _hannarose_ eh furniturestore… maymay roots… caliunderground2 arroyo… mo kats
#
# Sampling + smoothing = 0.1:
# <s> i think kidderadventures mrandmrs ••happy tame_impala bklouchis backbends dejavumainst… korea gnite lovethisgirl igerssf andele glue turbo mrrobot urm punches officiallydone trips" danielgutierrez… collarsgreens bodycouture redvelvetcupcakes remy passengers ski gtta
# <s> i think igottagonow goodday chickenfeet dinners mas lector vallejo sscxwcxpdx watermelon leading thesepeepsarebananas heartthrob" tijuana jessie steadyjenny missing… calilife epicbmx casuu nwfutures… retreat… bottle fungus serve hooters memphis_77 theartsyflea
# <s> i think _jennifer_arredondo… butnotyet mount… smashbox metreon urge craftsoda ️our womencrushwednesdaycheck carpet cafebermano aruna booboobear fondue allthewayup lytro jersey 새우 christmasparty muggin' thestrand stalker fri-neigh groupeffort bandera… fashionable beautytip
# <s> i think follygirl how i've been limit a-negroes dixiechicks adage kierolovesyou taken' morton's michaeljacksonone steal madefromscratch upshipped north… 'less copley… watzreal cafedeolla ••darksaturn barronstorey… iminnocent ifitfitsisits goto fitmom pillars
# <s> i think fearthebeard avail brewery enrollment kevinhart persian purpleductions cockerspanielpuppy niggas gunnar wes_klain lacma… "break renewal jonathansison92 neli yay_maryann cheryldaviscasting racquetball sprinklescupcakes scarletthalo laketahoe… ness foodtrucknight michealjfox soulfulstylist pardo
#
# Sampling + smoothing = 1:
# <s> i think datsik… igotskillschallenge mercantile glencoco mayahuelsac… japanesestyle baeday towns justafewofmygirls burbankcomedyfestival… thesuitelife imafish usa2016 g-money agirlsbestfriend socalseasoncloser sounding smoking" film/camera sapporo… hangingout thousandsoffeetintheair outdoorsportsmanawards… kobeyear wholefoodstaproom ache laphing
# <s> i think rachelraycookware… lazylaafternoons anuvaone… whatismymouthdoing whymondayssuck owner/spotter theaters joymode babylulu she’s ️shot aspire cookies spur nomad snowed marbellacountryclub… wokeupwiththisview piyolive 1oaknation 10weeks fearthebeard malibucafe carporn mic person megasite
# <s> i think photo… winninginlife beads bathtub theusual l-viz ockids macbookpro wellness jefflorchphotography stupid- sisters catchingup danaisabellaa intakes hawkinshealth… cumpleaños sanitary hillsboro pftfamily holywood minimarshmallows… startedfromthebottomnowwehere ️while mangodavis vault todayisagoodday
# <s> i think sneeze" delays kost cowgirls gravityfalls marathon… road fitsyx watch tezzytheprince live… fl carveouttimeforart kingoftheworld stjames n connell gliché famille ️message takingbackbirthday david_nunez10 basic cronkite/ vvc tongue associationmarch…
# <s> i think lim claus holidayparty •just gettingready brendan's cannoli classic… maggiano… believen pinnacles… sutro gerona ️️we oriental mgbucao sound… itsucks… yerbabuenagardens maria type1diabetes originaltommys cuando thru gigantesf hobnail additions
#
# Sampling + smoothing = 5:
# <s> i think different laduree 80sparty itself bigbrowneyes salam meandmybrother ruby thedinah2016 elchapo allstars myloves… photograph… menwithstreetstyle chrisbrown dragonballz noodle callmecrasian… galt bistro onlylawyers katherine_maya angelasuttey urbanskincaresd gabbie don’t candid
# <s> i think maddie grit_wit luscious gousa tiphanyadams beefpho sunset 24fitness# dontevenask imjustfeelinmyself supermariobrothers recovered ・・for brittneygirl… bri 121616 iamjusticelane believe… martin sista doitforthegram… downtownsanjose exec homeimprovement… timoteo againn stayhot
# <s> i think otheezystyledittoo akeem beautifuldaytoday… athletica… picturetime mcmfab takin' "lunches fullhouse pmbryantstudios baylove stupendous htpla 90% adlife fatty's juss followmylife_fml808 marino witz slalom accoustic 48th lp720 accessoriesoftheday… mexijew loveit
# <s> i think styled_seattle yayarea expression hanukkah twig gravityfalls comedy… xxoo# davis… joellen sticktogether 200" achristmasstory 4answers internationally goft… studio# tha ndnu duo "turnup" babybump neph firstrow edmfamily alki townish
# <s> i think theerealkarlaj balanced email musem kero23news heavengala2017 carols adidasxbait… 98 24/7 sumnermeadowsdogpark v-taper luvsic ye bravesoldiers gooz's studio20700 thenewjazzercise lacethatshoeonup liberty sunlifeorganics fitnessaddict cave9/15 februaryphotochallenge tofu ∙∙# jojo_the_techichi
#
# Start: ['<s>', 'the', 'model']
#
# Greedy:
# <s> the model # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> #
# <s> the model # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> #
# <s> the model # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> #
# <s> the model # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> #
# <s> the model # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> # <unk> #
#
# Sampling:
# <s> the model is an amazing hosts ️️we appreciate you two business this amazing intro . . ️ to be unstoppable happy to unpack a first christmas ️ her one
# <s> the model | photo @ bellagio las vegas , fulfilling and smile more fab night was only here we ️ @ supercuts in boise , california </s>
# <s> the model citizen @ park </s>
# <s> the model @ the grand backlot # everysaturdaynight… </s>
# <s> the model sam @ clifton's cafeteria to date night was had a wrap party … </s>
#
# Sampling + smoothing = 0.01:
# <s> the model likesforlikes kid's onlyinvegas… damn 395 bestplaceonearth fisherman merms pony *act* per waterfront… fundaysunday oldskool… allsuite brie freshempire "||full sundaybloodysunday enagic nightdrive… christmas-tree grandsonsareawesome timetowork… primera… vesta getoutside
# <s> the model smileypiercing dp sweaxy… beckclair havin canary instayum… phil… </s>
# <s> the model injured palladium butterflyeffectx360 atwater/n coa drip lovelife… off# itworks… hurdlerswag 1yearanniversary boogiebrutha hualapai stephens nine scattered repostby graciano's napoleon worker vanessacreations iamjemere fbo ramada soldiers ️have mso
# <s> the model warrior herpnwlife monstersdance messiah futbol… seniors hott jolla… bryce firstrow powerhouse teragram flika tre slap funny… runbuds inez werfit… melusine genuinepeople jody's simplyleopard 60+ lawondercon ocfair2016 oldfriends#
# <s> the model 1oaknation poledancing… sci-arc oaklandraiders dissent ️tini nighttime tapein simpcity tis' travelbuddies woman" dukevsunlv… deepthroat barhopping class specslive・・heading marvel dutch phi palmtrees stepping… sucker arrow hunington prettyinpink motion
#
# Sampling + smoothing = 0.1:
# <s> the model peaceful nib remy bigsandiego… pocketme glover toyotachr 6/18/15 janna irons }# csusbadmissions… way2ill enjoyingherself youcheckedthetag fashionable reaching hp mornin' besides shit'n jolt died laugher vrearly kravestudios thedab
# <s> the model luncheon shiieett routine… gro check-ins dittaproductions cows dwe clarksalonandspa congratulation 160hp "afflicted" 17kills raider wutang… soundtracktomylife esters dancer oy aoki daysofourlives grandparents' amerjegotvocals midweekplaytime… un-cropped lovethesegirls omg
# <s> the model quetzal… bioshot filtersarelife meyer suburbia souls lasagna nerdist clubzion "great i prunedale extend carrie's persimmon… salon" 小鹿 pannikin bistro track weeksareel iamjwatson quemfazcomamorfazmelhor lucky piedmont vez" adkinson
# <s> the model prgnx streetstyle dontwannagoback… rvcc baybay updates sapphire still… montage eyecandys harajuku… -stevie alejandrofernandez completely tinga latc roomie starcitymeltdown polenta yucaipa acaibowl jaded themedia lolesports christmassing thewho… blackmodel
# <s> the model concha silentsavasana frosty chrochet kenwood favourite… trilogy labarba honeymooners 149's pretenders focusst batteries bringiton2016 19thdayinus bayarea… poolside dans abeautifulplace sfgc maiden saturday… bealight bvillain walkingwithsieva disappointed cheetocat
#
# Sampling + smoothing = 1:
# <s> the model buzzed labordoodle "first jake_tahoe chinatown fidelis samples ・・dropping puerta for tahoebound lifeisgood abbey mints metime ceiling swatopia pursuit badger baladinoband jonvalera cecphotos… express… angl whereintheworldisthehealthyvoyager… excited hmc…
# <s> the model mylosers fashionmiamistyles… chefslife datcalilyfedoe mixology101 sincere trekell 44rbl… nojunk jas bbtm juanandonly nikkistapleton… toyota cabrillo panera shy $$45 archess detail strattomatic magnet lasvegasstrip champions gnitour sesame ⠀⠀
# <s> the model allgasnobrake banging shatto keeppushing spring hautelook co/myeukwejfa onix homewood fireplace mmj encore… parqbunnies madeup isla mezcal emanuel vegan… dmcoffee bus squat… us… gainzchaser alfred buythis australian parade
# <s> the model hotel… sunny… georgehaasphoto jiujitsu vascular dlphotoproblems happybirthdaymyla carmelbythesea panchito leoarmand showtek lacoste travel2016 spectacular… rollicking dirtybird empowered wsn tipjar 2nd mikeheadlyy giada selfiee despedida adelelive2016 surfandsandlaguna… remyproducers
# <s> the model momiji origin homage csusb's 6degrees… mondaymood heatoc foo" shh thankyouforthelove bellaelyseramsey coles midlo bandit punkmulan wat gliché tocamadera rishi disneyside… bball whatiworetoday cheek laesclavablanca ️sweet countdowntochristmas… ediefake
#
# Sampling + smoothing = 5:
# <s> the model coppering dandorn harpist tashy1008 jheneaiko weloveoakland y'all moments lalala calibash2016 fabulous… sundress happybirthdaymike misteamoconamor shamu's geometrical/irregular enchantedla oreo 3day carousel bossqueenrules bryanbaysore ok… aerospace craftsmanship svcc… bikram
# <s> the model todaysquats erik__g essencemag mushrooms menagerie slo hundred xs packingdistrict 55mm livin' luh excited… forest… beautybehindthemadness gillson twangsunday mentalhealth sandiegoliving… beachlife spreading sequence soakcity thesonsofanakin granite scheana universalstudios…
# <s> the model weloveourpatients factoryprla contouring backside chicalicrew shorthairdntcare idi happyfriday droppin' thewknd16 godblessthefirefighters areola parisienne yogawithmyyogi braces mondaysnowday hahas tt oldschool andaz dahliasocietyofsanfrancisco… dogdaycare maxy daffodil nbk world-disneyland tinytotspreschool
# <s> the model mph_1952… tomdouglas starboy heritage dogdad instapug manifestation facebook_live worklife… fertitta kellee picture$ shoutout stanley kmei2121 capsulecollection activefocus… fairmont gt3rs betapi1938 heaven… youcantoo springline gange thurmanatorr beautymakeup thewalkingdead
# <s> the model rito retzlaff madonnacollection bellamoxica oregonlife boone kendo kristen shaq catchin disneybound… use… hkdisney northside… payoff trek new… kennychesney reclinerseats accessories laborday2016 singing samovar ubie3 well-deserved haay geston

# %% [markdown]
# #### Answer Exercise 14
#
# ##### Part 1:
# **Greedy:**
#
# Greedy is fully deterministic: all 5 generations are identical. In my output it immediately collapses into a repetitive pattern dominated by unk and #.
# That happens because greedy always picks the single most likely token, and once it enters a high-probability loop (like unk / #), it keeps repeating it.
#
# **Sampling (no smoothing):**
#
# Sampling gives high diversity: all 5 generations differ.
# The sequences look more “sentence-like” sometimes (“thank you…”, “every day…”), but they can also become noisy or end suddenly.
# It sometimes reaches /s  naturally, but sometimes keeps going until max_tokens (especially when the model doesn’t strongly prefer EOS).
# Overall: more interesting than greedy, but less stable.
#
# **Sampling with smoothing**
#
# **smoothing = 0.01:**
#
# still influenced by the model counts, but already produces many rare/weird tokens and tags. Outputs look like long streams of usernames/hashtags.
#
# **smoothing = 0.1:**
#
# more randomness; coherence drops further. The text becomes more like a bag of tokens, fewer grammatical structures.
#
# **smoothing = 1:**
#
# very exploratory; lots of unrelated tokens and “Instagram-like” vocabulary, very low coherence.
#
# **smoothing = 5:**
#
# close to near-uniform behavior; outputs are highly random and mostly lists of tokens, with minimal structure.
#
# **Trend:**
#
# As smoothing increases, diversity increases but coherence decreases.
#
# #### Part 2
# I tested 3 starts: ["s", "you", "can"], ["s", "i", "think"], and ["s", "the", "model"].
#
# **Greedy**
#
# For each start, greedy again becomes deterministic and repeats the same continuation in all 5 runs.
# It often falls into repetitive “high-frequency token” loops like @ user @ user ... or unk chains.
# This shows greedy is sensitive to local maxima in the distribution and can get stuck in repetitive patterns.
#
# **Sampling:**
#
# Sampling keeps the prompt intact and creates varied sentences.
# The outputs are more or less prompt-related (e.g., “you can …”, “i think …”, “the model …”) but often drift into noisy hashtag/user/token sequences.
# Still, we think that it is better than the greedy approach.
#
# **Sampling + smoothing:**
#
# Same trend as Part 1: higher smoothing → more randomness and less coherence.
# At small smoothing (0.01), the start phrase influences the output a bit, but it still quickly becomes token-noise.
# At large smoothing (5), the start has less effect because the distribution becomes flatter.

# %% [markdown]
# ## 4. Perplexity
#
# In this section, we will implement and use perplexity as the metric that will help us judge which language model is the best. For this we will first calculate probabilities of each token in a sequence, depending on the previous tokens. For numerical stability, we will actually use logarithms of probabilities.

# %% [markdown]
# <a name='e15'></a>
# ### Exercise 15: Calculate sequence probabilities
#
# (4p) Fill the following function to calculate the logarithms of probabilities of each token in a sequence of tokens. Apply smoothing when calculating the probability. You can first calculate the probability (with smoothing) and then apply `numpy.log()` function.

# %%
def calculate_total_logprob_smoothing(tokens, language_model, smoothing=0.0):
    logprobs = np.zeros(len(tokens), dtype=float)
    for i in range(0, len(tokens)):
        previous_tokens = tokens[:i]
        current_token = tokens[i]
        ### YOUR CODE ENDS HERE
        V = language_model.vocab_size
        counts = language_model.get_counts(previous_tokens)

        smoothed_counts = counts + smoothing
        total = counts.sum() + smoothing * V

        token_idx = language_model.word_to_index[current_token]

        if total == 0:
            prob = 1.0 / V
        else:
            prob = smoothed_counts[token_idx] / total

        logprobs[i] = np.log(prob)
        ### YOUR CODE ENDS HERE
    total_logprob = logprobs.sum()
    return total_logprob

# %% [markdown]
# <a name='e16'></a>
# ### Exercise 16: Calculate sentence perplexity
#
# (4p) In this exercise, you will use the function above to calculate the perplexity. Consult the slides for the formulation that depends on the logarithm of probability.

# %%
def calculate_perplexity(tokens, languge_model, smoothing=0.0):
    total_logprob = calculate_total_logprob_smoothing(tokens, languge_model, smoothing)
    ### YOUR CODE ENDS HERE
    N = len(tokens)
    perplexity = np.exp(-total_logprob / N)

    ### YOUR CODE ENDS HERE
    return perplexity

# %% [markdown]
# We can test our function:

# %%
tokens = dataset['train'][0]['tokens']
print(tokens)

perplexity = calculate_perplexity(tokens, bigram_lm, smoothing=1.0)
print(perplexity)
# Out:
# ['<s>', 'sunday', 'afternoon', 'walking', 'through', 'venice', 'in', 'the', 'sun', 'with', '@', 'user', '️', '️', '️', '@', 'abbot', 'kinney', ',', 'venice', '</s>']
# 1219.6515961675798

# %% [markdown]
# <a name='e17'></a>
# ### Exercise 17: Perplexity of sentences
# (4p) Calculate perplexities of several (at least 5) sentences of your choice. Try different values of smoothing. Discuss the results: do the perplexities align with what you expected?

# %%
### YOUR CODE HERE

test_sentences = [
   dataset['train'][0]['tokens'],  
    dataset['train'][100]['tokens'], 
    dataset['train'][500]['tokens'],
    dataset['train'][1000]['tokens'],
    dataset['train'][2000]['tokens']
]

for i, tokens in enumerate(test_sentences, 1):
    print(f"Sentence {i}: {' '.join(tokens)}\n")

# different smoothing values
smoothing_values = [0.0, 0.001, 0.01, 0.1, 0.5, 1.0]

results = []
for i, tokens in enumerate(test_sentences, 1):
    sentence_results = {'sentence': i, 'length': len(tokens)}
    for smooth in smoothing_values:
        perp = calculate_perplexity(tokens, bigram_lm, smoothing=smooth)
        sentence_results[f'smooth_{smooth}'] = perp
    results.append(sentence_results)

df_perplexity = pd.DataFrame(results)
display(df_perplexity)

plt.figure(figsize=(10, 6))
for i, row in enumerate(results):
    perps = [row[f'smooth_{s}'] for s in smoothing_values]
    plt.plot(smoothing_values, perps, marker='o', label=f'Sentence {i+1} (len={row["length"]})')

plt.xlabel('Smoothing Parameter', fontsize=12)
plt.ylabel('Perplexity', fontsize=12)
plt.title('Perplexity vs Smoothing for Different Sentences', fontsize=14)
plt.legend()
plt.grid(True, alpha=0.3)
plt.xscale('log')
plt.yscale('log')
plt.tight_layout()
plt.show()

custom_texts = [
    "i love this",
    "thank you so much",
    "this is the best day ever",
    "I want to eat asian food",
    "Where can I find the next train station?"
]

for text in custom_texts:
    tokens = tokenize(text, vocab, unknown_token, bos_token, eos_token)
    print(f"\nText: '{text}'")
    print(f"Tokens: {tokens}")
    print(f"Perplexities:")
    for smooth in [0.01, 0.1, 1.0]:
        perp = calculate_perplexity(tokens, bigram_lm, smoothing=smooth)
        print(f"  α={smooth}: {perp:.2f}")
# Out:
# Sentence 1: <s> sunday afternoon walking through venice in the sun with @ user ️ ️ ️ @ abbot kinney , venice </s>
#
# Sentence 2: <s> ️ @ yosemite wilderness </s>
#
# Sentence 3: <s> yo i used to be so excited to see keni's 11 : 11 tweets </s>
#
# Sentence 4: <s> @ user @ user @ user # kpd2016 @ classic bowling center </s>
#
# Sentence 5: <s> # repost @ user with repostapp・・team l . a . # losangeles # california # vacay… </s>
#    sentence  length  smooth_0.0  smooth_0.001  smooth_0.01  smooth_0.1  \
# 0         1      21   42.766960     53.940294    96.205654  270.602722
# 1         2       6   77.163130    111.814402   204.433062  468.152478
# 2         3      16   63.309843    108.009891   245.076296  902.938296
# 3         4      14   33.359556     51.544184    83.449843  166.228489
# 4         5      18   46.623245     74.199864   111.647441  226.948200
#
#     smooth_0.5   smooth_1.0
# 0   743.873243  1219.651596
# 1  1016.711056  1521.575412
# 2  2789.930216  4514.678504
# 3   330.422187   474.263770
# 4   482.131797   716.899099
# Text: 'i love this'
# Tokens: ['<s>', 'i', 'love', 'this', '</s>']
# Perplexities:
#   α=0.01: 152.24
#   α=0.1: 226.07
#   α=1.0: 710.52
#
# Text: 'thank you so much'
# Tokens: ['<s>', 'thank', 'you', 'so', 'much', '</s>']
# Perplexities:
#   α=0.01: 95.05
#   α=0.1: 206.69
#   α=1.0: 858.73
#
# Text: 'this is the best day ever'
# Tokens: ['<s>', 'this', 'is', 'the', 'best', 'day', 'ever', '</s>']
# Perplexities:
#   α=0.01: 129.70
#   α=0.1: 274.43
#   α=1.0: 1153.86
#
# Text: 'I want to eat asian food'
# Tokens: ['<s>', '<unk>', 'want', 'to', 'eat', 'asian', 'food', '</s>']
# Perplexities:
#   α=0.01: 2658.19
#   α=0.1: 3464.65
#   α=1.0: 6841.76
#
# Text: 'Where can I find the next train station?'
# Tokens: ['<s>', '<unk>', 'can', '<unk>', 'find', 'the', 'next', 'train', '<unk>', '</s>']
# Perplexities:
#   α=0.01: 2151.64
#   α=0.1: 2671.15
#   α=1.0: 5508.00

# %% [markdown]
# ### Answers for exercise 17
#
# In the first part we calculated the Perplexity for 5 different tweets from the dataset, each for 5 different smoothing values.
#
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sentence</th>
#       <th>length</th>
#       <th>smooth_0.0</th>
#       <th>smooth_0.001</th>
#       <th>smooth_0.01</th>
#       <th>smooth_0.1</th>
#       <th>smooth_0.5</th>
#       <th>smooth_1.0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>22</td>
#       <td>38.975001</td>
#       <td>48.663511</td>
#       <td>84.614185</td>
#       <td>227.983039</td>
#       <td>605.962236</td>
#       <td>982.275324</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>6</td>
#       <td>76.794825</td>
#       <td>111.281523</td>
#       <td>203.472014</td>
#       <td>466.209660</td>
#       <td>1013.905658</td>
#       <td>1518.606731</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>16</td>
#       <td>59.229152</td>
#       <td>119.375290</td>
#       <td>280.011325</td>
#       <td>988.713265</td>
#       <td>2869.533817</td>
#       <td>4533.874416</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>14</td>
#       <td>33.062728</td>
#       <td>51.088133</td>
#       <td>82.735515</td>
#       <td>164.988074</td>
#       <td>328.756188</td>
#       <td>472.557040</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>19</td>
#       <td>35.892452</td>
#       <td>56.688388</td>
#       <td>88.898951</td>
#       <td>189.370150</td>
#       <td>398.690902</td>
#       <td>585.974106</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# As you can see the perplexity for smoothing values of 0.001 always is the lowest, for all sentences. The lowest perplexities have been recorded was for the sentence:
# **"sunday afternoon walking through venice in the sun with @user ️ ️ ️ @ abbot kinney , venice*"**
#
# In the graph you can inspect the different curves for the sentences and how the perplexity evolves for different smoothing factors, the table above provides you with the concrete values.
#
# After that we made up some own sentences:
#
# ### Text 1
# **Sentence:** "i love this"
#
# **Perplexities:**
#
# | α | Perplexity |
# |---|------------|
# | 0.01 | 149.13 |
# | 0.1  | 224.69 |
# | 1.0  | 714.11 |
#
# ---
#
# ### Text 2
# **Sentence:** "thank you so much"
#
# **Perplexities:**
#
# | α | Perplexity |
# |---|------------|
# | 0.01 | 95.00 |
# | 0.1  | 207.29 |
# | 1.0  | 862.33 |
#
# ---
#
# ### Text 3
# **Sentence:** "this is the best day ever"
#
# **Perplexities:**
#
# | α | Perplexity |
# |---|------------|
# | 0.01 | 129.81 |
# | 0.1  | 275.16 |
# | 1.0  | 1158.08 |
#
# ---
#
# ### Text 4
# **Sentence:** "I want to eat asian food"
#
# **Perplexities:**
#
# | α | Perplexity |
# |---|------------|
# | 0.01 | 1315.57 |
# | 0.1  | 1971.84 |
# | 1.0  | 4443.65 |

# %% [markdown]
# <a name='e18'></a>
# ### Exercise 18: Perplexity of the whole dataset
#
# (4p) Now we will calculate the perplexity of the entire dataset (or a subset). The function you will implement should calculate the logarithms of probabilities and the lengths of each of the sequences in the dataset. We need both to correctly calculate the perplexity per token.

# %%
def calculate_perplexity_dataset(dataset, languge_model, smoothing=0.0):
    all_logprobs = []
    all_lengths = []
    ### YOUR CODE ENDS HERE
    
    for example in tqdm.tqdm(dataset):
        tokens = example['tokens']
        total_logprob = calculate_total_logprob_smoothing(tokens, languge_model, smoothing)
        all_logprobs.append(total_logprob)
        all_lengths.append(len(tokens))
    
    # applying PP= exp(-sum(logprobs) / sum(lengths))
    total_logprob = np.sum(all_logprobs)
    total_length = np.sum(all_lengths)
    perplexity = np.exp(-total_logprob / total_length)
    
    ### YOUR CODE ENDS HERE
    return perplexity

# %% [markdown]
# Now, let's calculate the perplexity of the validation dataset.

# %%
validation_perplexity = calculate_perplexity_dataset(dataset['validation'], bigram_lm, smoothing=1.0)
print('validation perplexity', validation_perplexity)
# Out:
# 100%|██████████| 5000/5000 [00:27<00:00, 180.98it/s]
# validation perplexity 1831.445495329447

# %% [markdown]
# ## 5. Comparing Language Models
# In this final section, you will use all of the above to evaluate different models against each other. While this is a single exercise, you are expected add as many code and markdown cells as you wish. You can plot the results, add tables, etc.

# %% [markdown]
# The models should be evaluated on the `test` subset of the dataset. None of the models should have "seen" it during training and any hyperparameter tuning (if applicable). Below, you can see how we can use our function `calculate_perplexity_dataset()` to calculate the perplexity:

# %%
test_perplexity = calculate_perplexity_dataset(dataset['test'], bigram_lm, smoothing=1.0)
print('test perplexity', test_perplexity)
# Out:
# 100%|██████████| 50000/50000 [04:57<00:00, 167.79it/s]
# test perplexity 1524.960036674817

# %% [markdown]
# This could take couple of minutes. To test your code you can select a subset of this dataset. But make sure to report the final results in the exercise below on the full test set.

# %%
test_1000_perplexity = calculate_perplexity_dataset(dataset['test'].select(range(1000)), bigram_lm, smoothing=1.0)
print('test (1000 examples) perplexity', test_1000_perplexity)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 162.11it/s]
# test (1000 examples) perplexity 1441.678571061219

# %% [markdown]
# <a name='e19'></a>
# ### Exercise 19: More Advanced Language Model
# (20p) In this exercise, implement either an interpolation or backoff language model that combines more than one n-gram counter.
# Make sure to adjust weights based on the perplexity of the validation dataset.
# Compare the tuned model with previous models on the test set. Include n-grams with different values of n.
# Discuss the results.
#
# #### Requirements:
# - create n-gram language models with higher values of n,
# - implement at least one more advanced (combining multiple n-grams) language model,
# - tune its weights on the `validation` subset,
# - compare the model(s) against the basic models,
# - discuss the results (Are the results as expected? Why? Why not? etc.)
